# %%
import json
import pickle
import requests
import sqlite3

from bs4 import BeautifulSoup
from movie_info import RatingDistribution, Media, Movie

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
imdb_url = 'https://www.imdb.com'

# %% [markdown]
# ##### Определение вспомогательных функций

# %%
def get_main_tag(imdb_related_url, headers=headers):
    response = requests.get(imdb_related_url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')
    body_tag = soup.head.next_sibling
    div_tag__next = body_tag.find('div', id='__next', recursive=False)
    return div_tag__next.find('main', recursive=False)

# %%
def remove_last_url_part(url):
    return url[:url.rfind('/')]

# %%
def save_object(obj, filename):
    with open(filename, 'wb') as outp:
        pickle.dump(obj, outp, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ##### Функция парсинга страницы с фильмом

# %%
def parse_movie_info(movie_page_url, headers=headers):
    main_tag = get_main_tag(movie_page_url, headers)
    section_outmost = main_tag.div.find('section', recursive=False)
    section_outer = section_outmost.find('section', recursive=False)
    genre_data = section_outer.find('div', {'data-testid': 'genres'})
    description_data = genre_data.next_sibling

    directors_data, writers_data, stars_data = description_data.next_sibling.find_all(
        'li', {'data-testid': 'title-pc-principal-credit'}
    )

    get_names = lambda data: (
        [item.text for item in list(data.children)[1].ul.find_all('li')]
    )
    directors = get_names(directors_data)
    writers = get_names(writers_data)
    stars = get_names(stars_data)
    
    genre_list_data = genre_data.find('div', class_='ipc-chip-list__scroller')
    genres = list(map(lambda s: s.text, genre_list_data.children))
    description = description_data.find('span', {'data-testid': 'plot-xl'}).text
    return (genres, description, directors, writers, stars)

# %%
test_movie_info = (
    parse_movie_info('https://www.imdb.com/title/tt0111161')
)
assert (test_movie_info == (
        ['Drama'],
        'Over the course of several years, two convicts form a friendship,'\
        ' seeking consolation and, eventually, redemption through basic compassion.',
        ['Frank Darabont'],
        ['Stephen King', 'Frank Darabont'],
        ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
    )
)
test_movie_info
# Out:
# (['Drama'],
#  'Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.',
#  ['Frank Darabont'],
#  ['Stephen King', 'Frank Darabont'],
#  ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'])

# %% [markdown]
# ##### Функция парсинга детализированного рейтинга

# %%
def parse_detailed_ratings(ratings_page, headers=headers):
    response = requests.get(ratings_page, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')

    script = soup.head.next_sibling.find('script', id='__NEXT_DATA__', recursive=False)
    if not script:
        raise
    script_text = script.text
    score_data_pos = script_text.find('histogramValues')
    if score_data_pos == -1:
        raise

    unneeded_data_pos = script_text[score_data_pos:].find('countryData')
    if unneeded_data_pos == -1:
        raise
    narrowed_data = script_text[score_data_pos: score_data_pos + unneeded_data_pos]
    start_data_pos = narrowed_data.find('[')
    end_data_pos = narrowed_data.rfind(']') + 1
    list_of_vote_info = json.loads(narrowed_data[start_data_pos:end_data_pos])

    rating_dist = RatingDistribution()
    for i in range(10):
        cur_vote_count = int(list_of_vote_info[i]['voteCount'])
        rating_dist[i + 1] = cur_vote_count
    return rating_dist

# %%
test_movie_rating_dist = parse_detailed_ratings('https://www.imdb.com/title/tt0111161/ratings')
assert isinstance(test_movie_rating_dist, RatingDistribution)
assert len(test_movie_rating_dist) == 10
test_movie_rating_dist
# Out:
# {1: 41912,
#  2: 5267,
#  3: 5733,
#  4: 7809,
#  5: 16299,
#  6: 31544,
#  7: 105498,
#  8: 333308,
#  9: 730016,
#  10: 1557486}

# %% [markdown]
# #### Парсинг фильмов

# %%
movies_href = '/chart/top'
movies_url = imdb_url + movies_href
movies_response = requests.get(movies_url, headers=headers)
movies_soup = BeautifulSoup(movies_response.text, 'lxml')

# %%
movies_iterator = movies_soup.find('ul', class_='ipc-metadata-list').children

# %%
movie_list = list(movies_iterator)
assert len(movie_list) == 250

# %%
movies_res = []
for movie_data in movie_list:
    a_title_tag = movie_data.find('a', class_='ipc-title-link-wrapper')
    movie_metadata = movie_data.find('div', class_='cli-title-metadata')
    rating_data = movie_metadata.next_sibling

    _, *rating_and_votes = rating_data.find('span').children
    user_rating = rating_and_votes[0].text
    str_vote_count = rating_and_votes[1].text[2:-1]

    metadata_text = tuple(map(lambda s: s.text, movie_metadata.children))
    if len(metadata_text) == 2:
        year_str, duration_str = metadata_text
        restriction_rating = None
    elif len(metadata_text) == 3:
        year_str, duration_str, restriction_rating = metadata_text
    else:
        raise

    if a_title_tag['href'] is None:
        raise

    movie_href = remove_last_url_part(a_title_tag['href'])
    rank_and_title = a_title_tag.text
    rank, title = rank_and_title.split('.', 1)
    rank = int(rank)
    title = title.strip()
    
    movie_page = imdb_url + movie_href
    genres, description, directors, writers, stars = parse_movie_info(movie_page)
    rating_dist = parse_detailed_ratings(movie_page + '/ratings')
    hours_and_minutes = duration_str.split(' ')
    hours_str = hours_and_minutes[0]
    hours = int(hours_str[:hours_str.find('h')])
    minutes = 0
    if len(hours_and_minutes) == 2:
        minutes_str = hours_and_minutes[1]
        minutes = int(minutes_str[:minutes_str.find('m')])
    year = int(year_str)
    duration = hours * 60 + minutes
    movie = Movie(rank=rank, title=title, rating_str=user_rating,
              vote_count=rating_dist.total_vote_count,
              directors=directors, writers=writers, stars=stars,
              year=year, genres=genres, description=description,
              rating_dist=rating_dist, duration=duration)
    movies_res.append(movie)
    print(movie, end='\n\n')
# Out:
# rank = 1
# title = Побег из Шоушенка
# rating = 9.3
# vote count = 2834872
# director(s) = ['Frank Darabont']
# writer(s) = ['Stephen King', 'Frank Darabont']
# star(s) = ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
# year = 1994
# genres = ['Drama']
# description = Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.
# duration = 142
#
# rank = 2
# title = Крёстный отец
# rating = 9.2
# vote count = 1975731
# director(s) = ['Francis Ford Coppola']
# writer(s) = ['Mario Puzo', 'Francis Ford Coppola']
# star(s) = ['Marlon Brando', 'Al Pacino', 'James Caan']
# year = 1972
# genres = ['Crime', 'Drama']
# description = Don Vito Corleone, head of a mafia family, decides to hand over his empire to his youngest son Michael. However, his decision unintentionally puts the lives of his loved ones in grave danger.
# duration = 175
#
# rank = 3
# title = Тёмный рыцарь
# rating = 9.0
# vote count = 2816161
# director(s) = ['Christopher Nolan']
# writer(s) = ['Jonathan Nolan', 'Christopher Nolan', 'David S. Goyer']
# star(s) = ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart']
# year = 2008
# genres = ['Action', 'Crime', 'Drama']
# description = When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.
# duration = 152
#
# rank = 4
# title = Крёстный отец 2
# rating = 9.0
# vote count = 1340935
# director(s) = ['Francis Ford Coppola']
# writer(s) = ['Francis Ford Coppola', 'Mario Puzo']
# star(s) = ['Al Pacino', 'Robert De Niro', 'Robert Duvall']
# year = 1974
# genres = ['Crime', 'Drama']
# description = The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.
# duration = 202
#
# rank = 5
# title = 12 рaзгневанных мужчин
# rating = 9.0
# vote count = 845928
# director(s) = ['Sidney Lumet']
# writer(s) = ['Reginald Rose']
# star(s) = ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam']
# year = 1957
# genres = ['Crime', 'Drama']
# description = The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.
# duration = 96
#
# rank = 6
# title = Список Шиндлера
# rating = 9.0
# vote count = 1424448
# director(s) = ['Steven Spielberg']
# writer(s) = ['Thomas Keneally', 'Steven Zaillian']
# star(s) = ['Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley']
# year = 1993
# genres = ['Biography', 'Drama', 'History']
# description = In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.
# duration = 195
#
# rank = 7
# title = Властелин колец: Возвращение короля
# rating = 9.0
# vote count = 1941250
# director(s) = ['Peter Jackson']
# writer(s) = ['J.R.R. Tolkien', 'Fran Walsh', 'Philippa Boyens']
# star(s) = ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen']
# year = 2003
# genres = ['Action', 'Adventure', 'Drama']
# description = Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.
# duration = 201
#
# rank = 8
# title = Криминальное чтиво
# rating = 8.9
# vote count = 2174420
# director(s) = ['Quentin Tarantino']
# writer(s) = ['Quentin Tarantino', 'Roger Avary']
# star(s) = ['John Travolta', 'Uma Thurman', 'Samuel L. Jackson']
# year = 1994
# genres = ['Crime', 'Drama']
# description = The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.
# duration = 154
#
# rank = 9
# title = Властелин колец: Братство кольца
# rating = 8.9
# vote count = 1968352
# director(s) = ['Peter Jackson']
# writer(s) = ['J.R.R. Tolkien', 'Fran Walsh', 'Philippa Boyens']
# star(s) = ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom']
# year = 2001
# genres = ['Action', 'Adventure', 'Drama']
# description = A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.
# duration = 178
#
# rank = 10
# title = Хороший, плохой, злой
# rating = 8.8
# vote count = 798277
# director(s) = ['Sergio Leone']
# writer(s) = ['Luciano Vincenzoni', 'Sergio Leone', 'Agenore Incrocci']
# star(s) = ['Clint Eastwood', 'Eli Wallach', 'Lee Van Cleef']
# year = 1966
# genres = ['Adventure', 'Western']
# description = A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.
# duration = 161
#
# rank = 11
# title = Форрест Гамп
# rating = 8.8
# vote count = 2209519
# director(s) = ['Robert Zemeckis']
# writer(s) = ['Winston Groom', 'Eric Roth']
# star(s) = ['Tom Hanks', 'Robin Wright', 'Gary Sinise']
# year = 1994
# genres = ['Drama', 'Romance']
# description = The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.
# duration = 142
#
# rank = 12
# title = Бойцовский клуб
# rating = 8.8
# vote count = 2270691
# director(s) = ['David Fincher']
# writer(s) = ['Chuck Palahniuk', 'Jim Uhls']
# star(s) = ['Brad Pitt', 'Edward Norton', 'Meat Loaf']
# year = 1999
# genres = ['Drama']
# description = An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.
# duration = 139
#
# rank = 13
# title = Властелин колец: Две крепости
# rating = 8.8
# vote count = 1750224
# director(s) = ['Peter Jackson']
# writer(s) = ['J.R.R. Tolkien', 'Fran Walsh', 'Philippa Boyens']
# star(s) = ['Elijah Wood', 'Ian McKellen', 'Viggo Mortensen']
# year = 2002
# genres = ['Action', 'Adventure', 'Drama']
# description = While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.
# duration = 179
#
# rank = 14
# title = Начало
# rating = 8.8
# vote count = 2499897
# director(s) = ['Christopher Nolan']
# writer(s) = ['Christopher Nolan']
# star(s) = ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Elliot Page']
# year = 2010
# genres = ['Action', 'Adventure', 'Sci-Fi']
# description = A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.
# duration = 148
#
# rank = 15
# title = Звёздные войны. Эпизод 5: Империя наносит ответный удар
# rating = 8.7
# vote count = 1357240
# director(s) = ['Irvin Kershner']
# writer(s) = ['Leigh Brackett', 'Lawrence Kasdan', 'George Lucas']
# star(s) = ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# year = 1980
# genres = ['Action', 'Adventure', 'Fantasy']
# description = After the Rebels are overpowered by the Empire, Luke Skywalker begins his Jedi training with Yoda, while his friends are pursued across the galaxy by Darth Vader and bounty hunter Boba Fett.
# duration = 124
#
# rank = 16
# title = Матрица
# rating = 8.7
# vote count = 2014794
# director(s) = ['Lana Wachowski', 'Lilly Wachowski']
# writer(s) = ['Lilly Wachowski', 'Lana Wachowski']
# star(s) = ['Keanu Reeves', 'Laurence Fishburne', 'Carrie-Anne Moss']
# year = 1999
# genres = ['Action', 'Sci-Fi']
# description = When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.
# duration = 136
#
# rank = 17
# title = Славные парни
# rating = 8.7
# vote count = 1232571
# director(s) = ['Martin Scorsese']
# writer(s) = ['Nicholas Pileggi', 'Martin Scorsese']
# star(s) = ['Robert De Niro', 'Ray Liotta', 'Joe Pesci']
# year = 1990
# genres = ['Biography', 'Crime', 'Drama']
# description = The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.
# duration = 145
#
# rank = 18
# title = Пролетая над гнездом кукушки
# rating = 8.7
# vote count = 1054504
# director(s) = ['Milos Forman']
# writer(s) = ['Lawrence Hauben', 'Bo Goldman', 'Ken Kesey']
# star(s) = ['Jack Nicholson', 'Louise Fletcher', 'Michael Berryman']
# year = 1975
# genres = ['Drama']
# description = In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.
# duration = 133
#
# rank = 19
# title = Семь
# rating = 8.6
# vote count = 1760267
# director(s) = ['David Fincher']
# writer(s) = ['Andrew Kevin Walker']
# star(s) = ['Morgan Freeman', 'Brad Pitt', 'Kevin Spacey']
# year = 1995
# genres = ['Crime', 'Drama', 'Mystery']
# description = Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.
# duration = 127
#
# rank = 20
# title = Эта замечательная жизнь
# rating = 8.6
# vote count = 489901
# director(s) = ['Frank Capra']
# writer(s) = ['Frances Goodrich', 'Albert Hackett', 'Frank Capra']
# star(s) = ['James Stewart', 'Donna Reed', 'Lionel Barrymore']
# year = 1946
# genres = ['Drama', 'Family', 'Fantasy']
# description = An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.
# duration = 130
#
# rank = 21
# title = Семь самураев
# rating = 8.6
# vote count = 361632
# director(s) = ['Akira Kurosawa']
# writer(s) = ['Akira Kurosawa', 'Shinobu Hashimoto', 'Hideo Oguni']
# star(s) = ['Toshirô Mifune', 'Takashi Shimura', 'Keiko Tsushima']
# year = 1954
# genres = ['Action', 'Drama']
# description = Farmers from a village exploited by bandits hire a veteran samurai for protection, who gathers six other samurai to join him.
# duration = 207
#
# rank = 22
# title = Интерстеллар
# rating = 8.7
# vote count = 2030692
# director(s) = ['Christopher Nolan']
# writer(s) = ['Jonathan Nolan', 'Christopher Nolan']
# star(s) = ['Matthew McConaughey', 'Anne Hathaway', 'Jessica Chastain']
# year = 2014
# genres = ['Adventure', 'Drama', 'Sci-Fi']
# description = When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.
# duration = 169
#
# rank = 23
# title = Молчание ягнят
# rating = 8.6
# vote count = 1516963
# director(s) = ['Jonathan Demme']
# writer(s) = ['Thomas Harris', 'Ted Tally']
# star(s) = ['Jodie Foster', 'Anthony Hopkins', 'Scott Glenn']
# year = 1991
# genres = ['Crime', 'Drama', 'Thriller']
# description = A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.
# duration = 118
#
# rank = 24
# title = Спасти рядового Райана
# rating = 8.6
# vote count = 1469720
# director(s) = ['Steven Spielberg']
# writer(s) = ['Robert Rodat']
# star(s) = ['Tom Hanks', 'Matt Damon', 'Tom Sizemore']
# year = 1998
# genres = ['Drama', 'War']
# description = Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.
# duration = 169
#
# rank = 25
# title = Город Бога
# rating = 8.6
# vote count = 789488
# director(s) = ['Fernando Meirelles', 'Kátia Lund']
# writer(s) = ['Paulo Lins', 'Bráulio Mantovani']
# star(s) = ['Alexandre Rodrigues', 'Leandro Firmino', 'Matheus Nachtergaele']
# year = 2002
# genres = ['Crime', 'Drama']
# description = In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.
# duration = 130
#
# rank = 26
# title = Жизнь прекрасна
# rating = 8.6
# vote count = 731030
# director(s) = ['Roberto Benigni']
# writer(s) = ['Vincenzo Cerami', 'Roberto Benigni']
# star(s) = ['Roberto Benigni', 'Nicoletta Braschi', 'Giorgio Cantarini']
# year = 1997
# genres = ['Comedy', 'Drama', 'Romance']
# description = When an open-minded Jewish waiter and his son become victims of the Holocaust, he uses a perfect mixture of will, humor and imagination to protect his son from the dangers around their camp.
# duration = 116
#
# rank = 27
# title = Зелёная миля
# rating = 8.6
# vote count = 1379898
# director(s) = ['Frank Darabont']
# writer(s) = ['Stephen King', 'Frank Darabont']
# star(s) = ['Tom Hanks', 'Michael Clarke Duncan', 'David Morse']
# year = 1999
# genres = ['Crime', 'Drama', 'Fantasy']
# description = A tale set on death row in a Southern jail, where gentle giant John possesses the mysterious power to heal people's ailments. When the lead guard, Paul, recognizes John's gift, he tries to help stave off the condemned man's execution.
# duration = 189
#
# rank = 28
# title = Человек-паук: Паутина вселенных
# rating = 8.6
# vote count = 319180
# director(s) = ['Joaquim Dos Santos', 'Kemp Powers', 'Justin K. Thompson']
# writer(s) = ['Phil Lord', 'Christopher Miller', 'Dave Callaham']
# star(s) = ['Shameik Moore', 'Hailee Steinfeld', 'Brian Tyree Henry']
# year = 2023
# genres = ['Animation', 'Action', 'Adventure']
# description = Miles Morales catapults across the multiverse, where he encounters a team of Spider-People charged with protecting its very existence. When the heroes clash on how to handle a new threat, Miles must redefine what it means to be a hero.
# duration = 140
#
# rank = 29
# title = Звёздные войны: Эпизод 4 - Новая надежда
# rating = 8.6
# vote count = 1428083
# director(s) = ['George Lucas']
# writer(s) = ['George Lucas']
# star(s) = ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# year = 1977
# genres = ['Action', 'Adventure', 'Fantasy']
# description = Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.
# duration = 121
#
# rank = 30
# title = Терминатор 2: Судный день
# rating = 8.6
# vote count = 1154972
# director(s) = ['James Cameron']
# writer(s) = ['James Cameron', 'William Wisher']
# star(s) = ['Arnold Schwarzenegger', 'Linda Hamilton', 'Edward Furlong']
# year = 1991
# genres = ['Action', 'Sci-Fi']
# description = A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten year old son John from an even more advanced and powerful cyborg.
# duration = 137
#
# rank = 31
# title = Назад в будущее
# rating = 8.5
# vote count = 1281293
# director(s) = ['Robert Zemeckis']
# writer(s) = ['Robert Zemeckis', 'Bob Gale']
# star(s) = ['Michael J. Fox', 'Christopher Lloyd', 'Lea Thompson']
# year = 1985
# genres = ['Adventure', 'Comedy', 'Sci-Fi']
# description = Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.
# duration = 116
#
# rank = 32
# title = Унесённые призраками
# rating = 8.6
# vote count = 825695
# director(s) = ['Hayao Miyazaki']
# writer(s) = ['Hayao Miyazaki']
# star(s) = ['Daveigh Chase', 'Suzanne Pleshette', 'Miyu Irino']
# year = 2001
# genres = ['Animation', 'Adventure', 'Family']
# description = During her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches and spirits, a world where humans are changed into beasts.
# duration = 125
#
# rank = 33
# title = Пианист
# rating = 8.5
# vote count = 892102
# director(s) = ['Roman Polanski']
# writer(s) = ['Ronald Harwood', 'Wladyslaw Szpilman']
# star(s) = ['Adrien Brody', 'Thomas Kretschmann', 'Frank Finlay']
# year = 2002
# genres = ['Biography', 'Drama', 'Music']
# description = During the WWII, acclaimed Polish musician Wladyslaw faces various struggles as he loses contact with his family. As the situation worsens, he hides in the ruins of Warsaw in order to survive.
# duration = 150
#
# rank = 34
# title = Паразиты
# rating = 8.5
# vote count = 914036
# director(s) = ['Bong Joon Ho']
# writer(s) = ['Bong Joon Ho', 'Han Jin-won']
# star(s) = ['Song Kang-ho', 'Lee Sun-kyun', 'Cho Yeo-jeong']
# year = 2019
# genres = ['Drama', 'Thriller']
# description = Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.
# duration = 132
#
# rank = 35
# title = Психо
# rating = 8.5
# vote count = 707498
# director(s) = ['Alfred Hitchcock']
# writer(s) = ['Joseph Stefano', 'Robert Bloch']
# star(s) = ['Anthony Perkins', 'Janet Leigh', 'Vera Miles']
# year = 1960
# genres = ['Horror', 'Mystery', 'Thriller']
# description = A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run and checks into a remote motel run by a young man under the domination of his mother.
# duration = 109
#
# rank = 36
# title = Гладиатор
# rating = 8.5
# vote count = 1586467
# director(s) = ['Ridley Scott']
# writer(s) = ['David Franzoni', 'John Logan', 'William Nicholson']
# star(s) = ['Russell Crowe', 'Joaquin Phoenix', 'Connie Nielsen']
# year = 2000
# genres = ['Action', 'Adventure', 'Drama']
# description = A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.
# duration = 155
#
# rank = 37
# title = Король лев
# rating = 8.5
# vote count = 1120585
# director(s) = ['Roger Allers', 'Rob Minkoff']
# writer(s) = ['Irene Mecchi', 'Jonathan Roberts', 'Linda Woolverton']
# star(s) = ['Matthew Broderick', 'Jeremy Irons', 'James Earl Jones']
# year = 1994
# genres = ['Animation', 'Adventure', 'Drama']
# description = Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.
# duration = 88
#
# rank = 38
# title = Леон
# rating = 8.5
# vote count = 1223796
# director(s) = ['Luc Besson']
# writer(s) = ['Luc Besson']
# star(s) = ['Jean Reno', 'Gary Oldman', 'Natalie Portman']
# year = 1994
# genres = ['Action', 'Crime', 'Drama']
# description = 12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.
# duration = 110
#
# rank = 39
# title = Американская история Икс
# rating = 8.5
# vote count = 1170194
# director(s) = ['Tony Kaye']
# writer(s) = ['David McKenna']
# star(s) = ['Edward Norton', 'Edward Furlong', "Beverly D'Angelo"]
# year = 1998
# genres = ['Crime', 'Drama']
# description = Living a life marked by violence, neo-Nazi Derek finally goes to prison after killing two black youths. Upon his release, Derek vows to change; he hopes to prevent his brother, Danny, who idolizes Derek, from following in his footsteps.
# duration = 119
#
# rank = 40
# title = Отступники
# rating = 8.5
# vote count = 1397809
# director(s) = ['Martin Scorsese']
# writer(s) = ['William Monahan', 'Alan Mak', 'Felix Chong']
# star(s) = ['Leonardo DiCaprio', 'Matt Damon', 'Jack Nicholson']
# year = 2006
# genres = ['Crime', 'Drama', 'Thriller']
# description = An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.
# duration = 151
#
# rank = 41
# title = Одержимость
# rating = 8.5
# vote count = 955046
# director(s) = ['Damien Chazelle']
# writer(s) = ['Damien Chazelle']
# star(s) = ['Miles Teller', 'J.K. Simmons', 'Melissa Benoist']
# year = 2014
# genres = ['Drama', 'Music']
# description = A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.
# duration = 106
#
# rank = 42
# title = Престиж
# rating = 8.5
# vote count = 1414647
# director(s) = ['Christopher Nolan']
# writer(s) = ['Jonathan Nolan', 'Christopher Nolan', 'Christopher Priest']
# star(s) = ['Christian Bale', 'Hugh Jackman', 'Scarlett Johansson']
# year = 2006
# genres = ['Drama', 'Mystery', 'Sci-Fi']
# description = After a tragic accident, two stage magicians in 1890s London engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.
# duration = 130
#
# rank = 43
# title = Могила светлячков
# rating = 8.5
# vote count = 301590
# director(s) = ['Isao Takahata']
# writer(s) = ['Akiyuki Nosaka', 'Isao Takahata']
# star(s) = ['Tsutomu Tatsumi', 'Ayano Shiraishi', 'Akemi Yamaguchi']
# year = 1988
# genres = ['Animation', 'Drama', 'War']
# description = A young boy and his little sister struggle to survive in Japan during World War II.
# duration = 89
#
# rank = 44
# title = Подозрительные лица
# rating = 8.5
# vote count = 1129897
# director(s) = ['Bryan Singer']
# writer(s) = ['Christopher McQuarrie']
# star(s) = ['Kevin Spacey', 'Gabriel Byrne', 'Chazz Palminteri']
# year = 1995
# genres = ['Crime', 'Drama', 'Mystery']
# description = The sole survivor of a pier shoot-out tells the story of how a notorious criminal influenced the events that began with five criminals meeting in a seemingly random police lineup.
# duration = 106
#
# rank = 45
# title = Seppuku
# rating = 8.6
# vote count = 65780
# director(s) = ['Masaki Kobayashi']
# writer(s) = ['Yasuhiko Takiguchi', 'Shinobu Hashimoto']
# star(s) = ['Tatsuya Nakadai', 'Akira Ishihama', 'Shima Iwashita']
# year = 1962
# genres = ['Action', 'Drama', 'Mystery']
# description = When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so challenges the clan's integrity.
# duration = 133
#
# rank = 46
# title = Casablanca
# rating = 8.5
# vote count = 597595
# director(s) = ['Michael Curtiz']
# writer(s) = ['Julius J. Epstein', 'Philip G. Epstein', 'Howard Koch']
# star(s) = ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid']
# year = 1942
# genres = ['Drama', 'Romance', 'War']
# description = A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco.
# duration = 102
#
# rank = 47
# title = 1+1
# rating = 8.5
# vote count = 910830
# director(s) = ['Olivier Nakache', 'Éric Toledano']
# writer(s) = ['Olivier Nakache', 'Éric Toledano', 'Philippe Pozzo di Borgo']
# star(s) = ['François Cluzet', 'Omar Sy', 'Anne Le Ny']
# year = 2011
# genres = ['Biography', 'Comedy', 'Drama']
# description = After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.
# duration = 112
#
# rank = 48
# title = Новые времена
# rating = 8.5
# vote count = 255484
# director(s) = ['Charles Chaplin']
# writer(s) = ['Charles Chaplin']
# star(s) = ['Charles Chaplin', 'Paulette Goddard', 'Henry Bergman']
# year = 1936
# genres = ['Comedy', 'Drama', 'Romance']
# description = The Tramp struggles to live in modern industrial society with the help of a young homeless woman.
# duration = 87
#
# rank = 49
# title = Новый кинотеатр «Парадизо»
# rating = 8.5
# vote count = 277481
# director(s) = ['Giuseppe Tornatore']
# writer(s) = ['Giuseppe Tornatore', 'Vanna Paoli']
# star(s) = ['Philippe Noiret', 'Enzo Cannavale', 'Antonella Attili']
# year = 1988
# genres = ['Drama', 'Romance']
# description = A filmmaker recalls his childhood when falling in love with the pictures at the cinema of his home village and forms a deep friendship with the cinema's projectionist.
# duration = 155
#
# rank = 50
# title = Окно во двор
# rating = 8.5
# vote count = 514291
# director(s) = ['Alfred Hitchcock']
# writer(s) = ['John Michael Hayes', 'Cornell Woolrich']
# star(s) = ['James Stewart', 'Grace Kelly', 'Wendell Corey']
# year = 1954
# genres = ['Mystery', 'Thriller']
# description = A photographer in a wheelchair spies on his neighbors from his Greenwich Village courtyard apartment window, and becomes convinced one of them has committed murder, despite the skepticism of his fashion-model girlfriend.
# duration = 112
#
# rank = 51
# title = Однажды на Диком Западе
# rating = 8.5
# vote count = 344836
# director(s) = ['Sergio Leone']
# writer(s) = ['Sergio Donati', 'Sergio Leone', 'Dario Argento']
# star(s) = ['Henry Fonda', 'Charles Bronson', 'Claudia Cardinale']
# year = 1968
# genres = ['Western']
# description = A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad.
# duration = 166
#
# rank = 52
# title = Чужой
# rating = 8.5
# vote count = 932443
# director(s) = ['Ridley Scott']
# writer(s) = ["Dan O'Bannon", 'Ronald Shusett']
# star(s) = ['Sigourney Weaver', 'Tom Skerritt', 'John Hurt']
# year = 1979
# genres = ['Horror', 'Sci-Fi']
# description = The crew of a commercial spacecraft encounters a deadly lifeform after investigating an unknown transmission.
# duration = 117
#
# rank = 53
# title = Огни большого города
# rating = 8.5
# vote count = 193264
# director(s) = ['Charles Chaplin']
# writer(s) = ['Charles Chaplin', 'Harry Carr', 'Harry Crocker']
# star(s) = ['Charles Chaplin', 'Virginia Cherrill', 'Florence Lee']
# year = 1931
# genres = ['Comedy', 'Drama', 'Romance']
# description = With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has fallen in love with a sightless flower girl accumulates money to be able to help her medically.
# duration = 87
#
# rank = 54
# title = Апокалипсис сегодня
# rating = 8.4
# vote count = 699354
# director(s) = ['Francis Ford Coppola']
# writer(s) = ['John Milius', 'Francis Ford Coppola', 'Michael Herr']
# star(s) = ['Martin Sheen', 'Marlon Brando', 'Robert Duvall']
# year = 1979
# genres = ['Drama', 'Mystery', 'War']
# description = A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.
# duration = 147
#
# rank = 55
# title = Джанго освобожденный
# rating = 8.5
# vote count = 1659682
# director(s) = ['Quentin Tarantino']
# writer(s) = ['Quentin Tarantino']
# star(s) = ['Jamie Foxx', 'Christoph Waltz', 'Leonardo DiCaprio']
# year = 2012
# genres = ['Drama', 'Western']
# description = With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation owner in Mississippi.
# duration = 165
#
# rank = 56
# title = Помни
# rating = 8.4
# vote count = 1301583
# director(s) = ['Christopher Nolan']
# writer(s) = ['Christopher Nolan', 'Jonathan Nolan']
# star(s) = ['Guy Pearce', 'Carrie-Anne Moss', 'Joe Pantoliano']
# year = 2000
# genres = ['Mystery', 'Thriller']
# description = A man with short-term memory loss attempts to track down his wife's murderer.
# duration = 113
#
# rank = 57
# title = Индиана Джонс: В поисках утраченного ковчега
# rating = 8.4
# vote count = 1023144
# director(s) = ['Steven Spielberg']
# writer(s) = ['Lawrence Kasdan', 'George Lucas', 'Philip Kaufman']
# star(s) = ['Harrison Ford', 'Karen Allen', 'Paul Freeman']
# year = 1981
# genres = ['Action', 'Adventure']
# description = In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before the Nazis can obtain its awesome powers.
# duration = 115
#
# rank = 58
# title = ВАЛЛ·И
# rating = 8.4
# vote count = 1178527
# director(s) = ['Andrew Stanton']
# writer(s) = ['Andrew Stanton', 'Pete Docter', 'Jim Reardon']
# star(s) = ['Ben Burtt', 'Elissa Knight', 'Jeff Garlin']
# year = 2008
# genres = ['Animation', 'Adventure', 'Family']
# description = In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.
# duration = 98
#
# rank = 59
# title = Жизнь других
# rating = 8.4
# vote count = 405087
# director(s) = ['Florian Henckel von Donnersmarck']
# writer(s) = ['Florian Henckel von Donnersmarck']
# star(s) = ['Ulrich Mühe', 'Martina Gedeck', 'Sebastian Koch']
# year = 2006
# genres = ['Drama', 'Mystery', 'Thriller']
# description = In 1984 East Berlin, an agent of the secret police, conducting surveillance on a writer and his lover, finds himself becoming increasingly absorbed by their lives.
# duration = 137
#
# rank = 60
# title = Sunset Blvd.
# rating = 8.4
# vote count = 232945
# director(s) = ['Billy Wilder']
# writer(s) = ['Charles Brackett', 'Billy Wilder', 'D.M. Marshman Jr.']
# star(s) = ['William Holden', 'Gloria Swanson', 'Erich von Stroheim']
# year = 1950
# genres = ['Drama', 'Film-Noir']
# description = A screenwriter develops a dangerous relationship with a faded film star determined to make a triumphant return.
# duration = 110
#
# rank = 61
# title = Тропы славы
# rating = 8.4
# vote count = 208868
# director(s) = ['Stanley Kubrick']
# writer(s) = ['Stanley Kubrick', 'Calder Willingham', 'Jim Thompson']
# star(s) = ['Kirk Douglas', 'Ralph Meeker', 'Adolphe Menjou']
# year = 1957
# genres = ['Drama', 'War']
# description = After refusing to attack an enemy position, a general accuses the soldiers of cowardice and their commanding officer must defend them.
# duration = 88
#
# rank = 62
# title = Мстители: Война бесконечности
# rating = 8.4
# vote count = 1174114
# director(s) = ['Anthony Russo', 'Joe Russo']
# writer(s) = ['Christopher Markus', 'Stephen McFeely', 'Stan Lee']
# star(s) = ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo']
# year = 2018
# genres = ['Action', 'Adventure', 'Sci-Fi']
# description = The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.
# duration = 149
#
# rank = 63
# title = Сияние
# rating = 8.4
# vote count = 1086814
# director(s) = ['Stanley Kubrick']
# writer(s) = ['Stephen King', 'Stanley Kubrick', 'Diane Johnson']
# star(s) = ['Jack Nicholson', 'Shelley Duvall', 'Danny Lloyd']
# year = 1980
# genres = ['Drama', 'Horror']
# description = A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.
# duration = 146
#
# rank = 64
# title = Человек-паук: Через Вселенные
# rating = 8.4
# vote count = 647595
# director(s) = ['Bob Persichetti', 'Peter Ramsey', 'Rodney Rothman']
# writer(s) = ['Phil Lord', 'Rodney Rothman']
# star(s) = ['Shameik Moore', 'Jake Johnson', 'Hailee Steinfeld']
# year = 2018
# genres = ['Animation', 'Action', 'Adventure']
# description = Teen Miles Morales becomes the Spider-Man of his universe and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.
# duration = 117
#
# rank = 65
# title = Свидетель обвинения
# rating = 8.4
# vote count = 134622
# director(s) = ['Billy Wilder']
# writer(s) = ['Agatha Christie', 'Billy Wilder', 'Harry Kurnitz']
# star(s) = ['Tyrone Power', 'Marlene Dietrich', 'Charles Laughton']
# year = 1957
# genres = ['Crime', 'Drama', 'Mystery']
# description = A veteran British barrister must defend his client in a murder trial that has surprise after surprise.
# duration = 116
#
# rank = 66
# title = Великий диктатор
# rating = 8.4
# vote count = 234298
# director(s) = ['Charles Chaplin']
# writer(s) = ['Charles Chaplin']
# star(s) = ['Charles Chaplin', 'Paulette Goddard', 'Jack Oakie']
# year = 1940
# genres = ['Comedy', 'Drama', 'War']
# description = Dictator Adenoid Hynkel tries to expand his empire while a poor Jewish barber tries to avoid persecution from Hynkel's regime.
# duration = 125
#
# rank = 67
# title = Чужой 2
# rating = 8.4
# vote count = 751355
# director(s) = ['James Cameron']
# writer(s) = ['James Cameron', 'David Giler', 'Walter Hill']
# star(s) = ['Sigourney Weaver', 'Michael Biehn', 'Carrie Henn']
# year = 1986
# genres = ['Action', 'Adventure', 'Sci-Fi']
# description = Decades after surviving the Nostromo incident, Ellen Ripley is sent out to re-establish contact with a terraforming colony but finds herself battling the Alien Queen and her offspring.
# duration = 137
#
# rank = 68
# title = Оппенгеймер
# rating = 8.4
# vote count = 564470
# director(s) = ['Christopher Nolan']
# writer(s) = ['Christopher Nolan', 'Kai Bird', 'Martin Sherwin']
# star(s) = ['Cillian Murphy', 'Emily Blunt', 'Matt Damon']
# year = 2023
# genres = ['Biography', 'Drama', 'History']
# description = The story of American scientist J. Robert Oppenheimer and his role in the development of the atomic bomb.
# duration = 180
#
# rank = 69
# title = Бесславные ублюдки
# rating = 8.4
# vote count = 1548981
# director(s) = ['Quentin Tarantino']
# writer(s) = ['Quentin Tarantino']
# star(s) = ['Brad Pitt', 'Diane Kruger', 'Eli Roth']
# year = 2009
# genres = ['Adventure', 'Drama', 'War']
# description = In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.
# duration = 153
#
# rank = 70
# title = Тёмный рыцарь: Возрождение легенды
# rating = 8.4
# vote count = 1795795
# director(s) = ['Christopher Nolan']
# writer(s) = ['Jonathan Nolan', 'Christopher Nolan', 'David S. Goyer']
# star(s) = ['Christian Bale', 'Tom Hardy', 'Anne Hathaway']
# year = 2012
# genres = ['Action', 'Drama', 'Thriller']
# description = Eight years after the Joker's reign of chaos, Batman is coerced out of exile with the assistance of the mysterious Selina Kyle in order to defend Gotham City from the vicious guerrilla terrorist Bane.
# duration = 164
#
# rank = 71
# title = Красота по-американски
# rating = 8.3
# vote count = 1196406
# director(s) = ['Sam Mendes']
# writer(s) = ['Alan Ball']
# star(s) = ['Kevin Spacey', 'Annette Bening', 'Thora Birch']
# year = 1999
# genres = ['Drama']
# description = A sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend.
# duration = 122
#
# rank = 72
# title = Доктор Стрейнджлав, или Как я научился не волноваться и полюбил атомную бомбу
# rating = 8.4
# vote count = 511134
# director(s) = ['Stanley Kubrick']
# writer(s) = ['Stanley Kubrick', 'Terry Southern', 'Peter George']
# star(s) = ['Peter Sellers', 'George C. Scott', 'Sterling Hayden']
# year = 1964
# genres = ['Comedy', 'War']
# description = An insane American general orders a bombing attack on the Soviet Union, triggering a path to nuclear holocaust that a war room full of politicians and generals frantically tries to stop.
# duration = 95
#
# rank = 73
# title = Олдбой
# rating = 8.4
# vote count = 620506
# director(s) = ['Park Chan-wook']
# writer(s) = ['Garon Tsuchiya', 'Nobuaki Minegishi', 'Park Chan-wook']
# star(s) = ['Choi Min-sik', 'Yoo Ji-tae', 'Kang Hye-jeong']
# year = 2003
# genres = ['Action', 'Drama', 'Mystery']
# description = After being kidnapped and imprisoned for fifteen years, Oh Dae-Su is released, only to find that he must find his captor in five days.
# duration = 120
#
# rank = 74
# title = Тайна Коко
# rating = 8.4
# vote count = 570072
# director(s) = ['Lee Unkrich', 'Adrian Molina']
# writer(s) = ['Lee Unkrich', 'Jason Katz', 'Matthew Aldrich']
# star(s) = ['Anthony Gonzalez', 'Gael García Bernal', 'Benjamin Bratt']
# year = 2017
# genres = ['Animation', 'Adventure', 'Drama']
# description = Aspiring musician Miguel, confronted with his family's ancestral ban on music, enters the Land of the Dead to find his great-great-grandfather, a legendary singer.
# duration = 105
#
# rank = 75
# title = Амадей
# rating = 8.4
# vote count = 421450
# director(s) = ['Milos Forman']
# writer(s) = ['Peter Shaffer', 'Zdenek Mahler']
# star(s) = ['F. Murray Abraham', 'Tom Hulce', 'Elizabeth Berridge']
# year = 1984
# genres = ['Biography', 'Drama', 'Music']
# description = The life, success and troubles of Wolfgang Amadeus Mozart, as told by Antonio Salieri, the contemporaneous composer who was deeply jealous of Mozart's talent and claimed to have murdered him.
# duration = 160
#
# rank = 76
# title = История игрушек
# rating = 8.3
# vote count = 1050380
# director(s) = ['John Lasseter']
# writer(s) = ['John Lasseter', 'Pete Docter', 'Andrew Stanton']
# star(s) = ['Tom Hanks', 'Tim Allen', 'Don Rickles']
# year = 1995
# genres = ['Animation', 'Adventure', 'Comedy']
# description = A cowboy doll is profoundly threatened and jealous when a new spaceman action figure supplants him as top toy in a boy's bedroom.
# duration = 81
#
# rank = 77
# title = Подводная лодка
# rating = 8.4
# vote count = 261206
# director(s) = ['Wolfgang Petersen']
# writer(s) = ['Wolfgang Petersen', 'Lothar G. Buchheim']
# star(s) = ['Jürgen Prochnow', 'Herbert Grönemeyer', 'Klaus Wennemann']
# year = 1981
# genres = ['Drama', 'War']
# description = A German U-boat stalks the frigid waters of the North Atlantic as its young crew experience the sheer terror and claustrophobic life of a submariner in World War II.
# duration = 149
#
# rank = 78
# title = Храброе сердце
# rating = 8.3
# vote count = 1077830
# director(s) = ['Mel Gibson']
# writer(s) = ['Randall Wallace']
# star(s) = ['Mel Gibson', 'Sophie Marceau', 'Patrick McGoohan']
# year = 1995
# genres = ['Biography', 'Drama', 'History']
# description = Scottish warrior William Wallace leads his countrymen in a rebellion to free his homeland from the tyranny of King Edward I of England.
# duration = 178
#
# rank = 79
# title = Мстители: Финал
# rating = 8.4
# vote count = 1235149
# director(s) = ['Anthony Russo', 'Joe Russo']
# writer(s) = ['Christopher Markus', 'Stephen McFeely', 'Stan Lee']
# star(s) = ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo']
# year = 2019
# genres = ['Action', 'Adventure', 'Drama']
# description = After the devastating events of Мстители: Война бесконечности (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.
# duration = 181
#
# rank = 80
# title = Джокер
# rating = 8.4
# vote count = 1434302
# director(s) = ['Todd Phillips']
# writer(s) = ['Todd Phillips', 'Scott Silver', 'Bob Kane']
# star(s) = ['Joaquin Phoenix', 'Robert De Niro', 'Zazie Beetz']
# year = 2019
# genres = ['Crime', 'Drama', 'Thriller']
# description = During the 1980s, a failed stand-up comedian is driven insane and turns to a life of crime and chaos in Gotham City while becoming an infamous psychopathic crime figure.
# duration = 122
#
# rank = 81
# title = Принцесса Мононоке
# rating = 8.3
# vote count = 422695
# director(s) = ['Hayao Miyazaki']
# writer(s) = ['Hayao Miyazaki', 'Neil Gaiman']
# star(s) = ['Yôji Matsuda', 'Yuriko Ishida', 'Yûko Tanaka']
# year = 1997
# genres = ['Animation', 'Action', 'Adventure']
# description = On a journey to find the cure for a Tatarigami's curse, Ashitaka finds himself in the middle of a war between the forest gods and Tatara, a mining colony. In this quest he also meets San, the Mononoke Hime.
# duration = 134
#
# rank = 82
# title = Умница Уилл Хантинг
# rating = 8.3
# vote count = 1038408
# director(s) = ['Gus Van Sant']
# writer(s) = ['Matt Damon', 'Ben Affleck']
# star(s) = ['Robin Williams', 'Matt Damon', 'Ben Affleck']
# year = 1997
# genres = ['Drama', 'Romance']
# description = Will Hunting, a janitor at M.I.T., has a gift for mathematics, but needs help from a psychologist to find direction in his life.
# duration = 126
#
# rank = 83
# title = Твоё имя
# rating = 8.4
# vote count = 307328
# director(s) = ['Makoto Shinkai']
# writer(s) = ['Makoto Shinkai', 'Clark Cheng']
# star(s) = ['Ryunosuke Kamiki', 'Mone Kamishiraishi', 'Ryo Narita']
# year = 2016
# genres = ['Animation', 'Drama', 'Fantasy']
# description = Two teenagers share a profound, magical connection upon discovering they are swapping bodies. Things manage to become even more complicated when the boy and girl decide to meet in person.
# duration = 106
#
# rank = 84
# title = Однажды в Америке
# rating = 8.3
# vote count = 371462
# director(s) = ['Sergio Leone']
# writer(s) = ['Harry Grey', 'Leonardo Benvenuti', 'Piero De Bernardi']
# star(s) = ['Robert De Niro', 'James Woods', 'Elizabeth McGovern']
# year = 1984
# genres = ['Crime', 'Drama']
# description = A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan 35 years later, where he must once again confront the ghosts and regrets of his old life.
# duration = 229
#
# rank = 85
# title = Три идиота
# rating = 8.4
# vote count = 424519
# director(s) = ['Rajkumar Hirani']
# writer(s) = ['Abhijat Joshi', 'Rajkumar Hirani', 'Vidhu Vinod Chopra']
# star(s) = ['Aamir Khan', 'Madhavan', 'Mona Singh']
# year = 2009
# genres = ['Comedy', 'Drama']
# description = Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them "idiots".
# duration = 170
#
# rank = 86
# title = Tengoku to jigoku
# rating = 8.4
# vote count = 51174
# director(s) = ['Akira Kurosawa']
# writer(s) = ['Hideo Oguni', 'Ryûzô Kikushima', 'Eijirô Hisaita']
# star(s) = ['Toshirô Mifune', 'Yutaka Sada', 'Tatsuya Nakadai']
# year = 1963
# genres = ['Crime', 'Drama', 'Mystery']
# description = An executive of a Yokohama shoe company becomes a victim of extortion when his chauffeur's son is kidnapped by mistake and held for ransom.
# duration = 143
#
# rank = 87
# title = Поющие под дождём
# rating = 8.3
# vote count = 256285
# director(s) = ['Stanley Donen', 'Gene Kelly']
# writer(s) = ['Betty Comden', 'Adolph Green']
# star(s) = ['Gene Kelly', "Donald O'Connor", 'Debbie Reynolds']
# year = 1952
# genres = ['Comedy', 'Musical', 'Romance']
# description = A silent film star falls for a chorus girl just as he and his delusionally jealous screen partner are trying to make the difficult transition to talking pictures in 1920s Hollywood.
# duration = 103
#
# rank = 88
# title = Капернаум
# rating = 8.4
# vote count = 101748
# director(s) = ['Nadine Labaki']
# writer(s) = ['Nadine Labaki', 'Jihad Hojeily', 'Michelle Keserwany']
# star(s) = ['Zain Al Rafeea', 'Yordanos Shiferaw', 'Boluwatife Treasure Bankole']
# year = 2018
# genres = ['Drama']
# description = While serving a five-year sentence for a violent crime, a 12-year-old boy sues his parents for neglect.
# duration = 126
#
# rank = 89
# title = Реквием по мечте
# rating = 8.3
# vote count = 884683
# director(s) = ['Darren Aronofsky']
# writer(s) = ['Hubert Selby Jr.', 'Darren Aronofsky']
# star(s) = ['Ellen Burstyn', 'Jared Leto', 'Jennifer Connelly']
# year = 2000
# genres = ['Drama']
# description = The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.
# duration = 102
#
# rank = 90
# title = Иди и смотри
# rating = 8.4
# vote count = 92845
# director(s) = ['Elem Klimov']
# writer(s) = ['Ales Adamovich', 'Elem Klimov']
# star(s) = ['Aleksey Kravchenko', 'Olga Mironova', 'Liubomiras Laucevicius']
# year = 1985
# genres = ['Drama', 'Thriller', 'War']
# description = After finding an old rifle, a young boy joins the Soviet resistance movement against ruthless German forces and experiences the horrors of World War II.
# duration = 142
#
# rank = 91
# title = История игрушек: Большой побег
# rating = 8.3
# vote count = 879050
# director(s) = ['Lee Unkrich']
# writer(s) = ['John Lasseter', 'Andrew Stanton', 'Lee Unkrich']
# star(s) = ['Tom Hanks', 'Tim Allen', 'Joan Cusack']
# year = 2010
# genres = ['Animation', 'Adventure', 'Comedy']
# description = The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned and to return home.
# duration = 103
#
# rank = 92
# title = Звёздные войны. Эпизод 6: Возвращение джедая
# rating = 8.3
# vote count = 1104381
# director(s) = ['Richard Marquand']
# writer(s) = ['Lawrence Kasdan', 'George Lucas']
# star(s) = ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher']
# year = 1983
# genres = ['Action', 'Adventure', 'Fantasy']
# description = After rescuing Han Solo from Jabba the Hutt, the Rebels attempt to destroy the second Death Star, while Luke struggles to help Darth Vader back from the dark side.
# duration = 131
#
# rank = 93
# title = Вечное сияние чистого разума
# rating = 8.3
# vote count = 1058436
# director(s) = ['Michel Gondry']
# writer(s) = ['Charlie Kaufman', 'Michel Gondry', 'Pierre Bismuth']
# star(s) = ['Jim Carrey', 'Kate Winslet', 'Tom Wilkinson']
# year = 2004
# genres = ['Drama', 'Romance', 'Sci-Fi']
# description = When their relationship turns sour, a couple undergoes a medical procedure to have each other erased from their memories for ever.
# duration = 108
#
# rank = 94
# title = Охота
# rating = 8.3
# vote count = 355787
# director(s) = ['Thomas Vinterberg']
# writer(s) = ['Thomas Vinterberg', 'Tobias Lindholm']
# star(s) = ['Mads Mikkelsen', 'Thomas Bo Larsen', 'Annika Wedderkopp']
# year = 2012
# genres = ['Drama']
# description = A teacher lives a lonely life, all the while struggling over his son's custody. His life slowly gets better as he finds love and receives good news from his son, but his new luck is about to be brutally shattered by an innocent little lie.
# duration = 115
#
# rank = 95
# title = 2001 год: Космическая одиссея
# rating = 8.3
# vote count = 707099
# director(s) = ['Stanley Kubrick']
# writer(s) = ['Stanley Kubrick', 'Arthur C. Clarke']
# star(s) = ['Keir Dullea', 'Gary Lockwood', 'William Sylvester']
# year = 1968
# genres = ['Adventure', 'Sci-Fi']
# description = After uncovering a mysterious artifact buried beneath the Lunar surface, a spacecraft is sent to Jupiter to find its origins: a spacecraft manned by two men and the supercomputer HAL 9000.
# duration = 149
#
# rank = 96
# title = Бешеные псы
# rating = 8.3
# vote count = 1070972
# director(s) = ['Quentin Tarantino']
# writer(s) = ['Quentin Tarantino', 'Roger Avary']
# star(s) = ['Harvey Keitel', 'Tim Roth', 'Michael Madsen']
# year = 1992
# genres = ['Crime', 'Thriller']
# description = When a simple jewelry heist goes horribly wrong, the surviving criminals begin to suspect that one of them is a police informant.
# duration = 99
#
# rank = 97
# title = Ikiru
# rating = 8.3
# vote count = 85448
# director(s) = ['Akira Kurosawa']
# writer(s) = ['Akira Kurosawa', 'Shinobu Hashimoto', 'Hideo Oguni']
# star(s) = ['Takashi Shimura', 'Nobuo Kaneko', "Shin'ichi Himori"]
# year = 1952
# genres = ['Drama']
# description = A bureaucrat tries to find meaning in his life after he discovers he has terminal cancer.
# duration = 143
#
# rank = 98
# title = Лоуренс Аравийский
# rating = 8.3
# vote count = 308984
# director(s) = ['David Lean']
# writer(s) = ['Robert Bolt', 'Michael Wilson']
# star(s) = ["Peter O'Toole", 'Alec Guinness', 'Anthony Quinn']
# year = 1962
# genres = ['Adventure', 'Biography', 'Drama']
# description = The story of T.E. Lawrence, the English officer who successfully united and led the diverse, often warring, Arab tribes during World War I in order to fight the Turks.
# duration = 218
#
# rank = 99
# title = Квартира
# rating = 8.3
# vote count = 192763
# director(s) = ['Billy Wilder']
# writer(s) = ['Billy Wilder', 'I.A.L. Diamond']
# star(s) = ['Jack Lemmon', 'Shirley MacLaine', 'Fred MacMurray']
# year = 1960
# genres = ['Comedy', 'Drama', 'Romance']
# description = A Manhattan insurance clerk tries to rise in his company by letting its executives use his apartment for trysts, but complications and a romance of his own ensue.
# duration = 125
#
# rank = 100
# title = Гражданин Кейн
# rating = 8.3
# vote count = 460242
# director(s) = ['Orson Welles']
# writer(s) = ['Herman J. Mankiewicz', 'Orson Welles', 'John Houseman']
# star(s) = ['Orson Welles', 'Joseph Cotten', 'Dorothy Comingore']
# year = 1941
# genres = ['Drama', 'Mystery']
# description = Following the death of publishing tycoon Charles Foster Kane, reporters scramble to uncover the meaning of his final utterance: 'Rosebud.'
# duration = 119
#
# rank = 101
# title = М убийца
# rating = 8.3
# vote count = 166028
# director(s) = ['Fritz Lang']
# writer(s) = ['Thea von Harbou', 'Fritz Lang', 'Egon Jacobsohn']
# star(s) = ['Peter Lorre', 'Ellen Widmann', 'Inge Landgut']
# year = 1931
# genres = ['Crime', 'Mystery', 'Thriller']
# description = When the police in a German city are unable to catch a child-murderer, other criminals join in the manhunt.
# duration = 117
#
# rank = 102
# title = На север через северо-запад
# rating = 8.3
# vote count = 341715
# director(s) = ['Alfred Hitchcock']
# writer(s) = ['Ernest Lehman']
# star(s) = ['Cary Grant', 'Eva Marie Saint', 'James Mason']
# year = 1959
# genres = ['Action', 'Adventure', 'Mystery']
# description = A New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies, and falls for a woman whose loyalties he begins to doubt.
# duration = 136
#
# rank = 103
# title = Головокружение
# rating = 8.3
# vote count = 420904
# director(s) = ['Alfred Hitchcock']
# writer(s) = ['Alec Coppel', 'Samuel A. Taylor', 'Pierre Boileau']
# star(s) = ['James Stewart', 'Kim Novak', 'Barbara Bel Geddes']
# year = 1958
# genres = ['Mystery', 'Romance', 'Thriller']
# description = A former San Francisco police detective juggles wrestling with his personal demons and becoming obsessed with the hauntingly beautiful woman he has been hired to trail, who may be deeply disturbed.
# duration = 128
#
# rank = 104
# title = Двойная страховка
# rating = 8.3
# vote count = 165160
# director(s) = ['Billy Wilder']
# writer(s) = ['Billy Wilder', 'Raymond Chandler', 'James M. Cain']
# star(s) = ['Fred MacMurray', 'Barbara Stanwyck', 'Edward G. Robinson']
# year = 1944
# genres = ['Crime', 'Drama', 'Film-Noir']
# description = A Los Angeles insurance representative lets an alluring housewife seduce him into a scheme of insurance fraud and murder that arouses the suspicion of his colleague, an insurance investigator.
# duration = 107
#
# rank = 105
# title = Лицо со шрамом
# rating = 8.3
# ...
# duration = 121
#
# rank = 215
# title = Логан
# rating = 8.1
# vote count = 814344
# director(s) = ['James Mangold']
# writer(s) = ['James Mangold', 'Scott Frank', 'Michael Green']
# star(s) = ['Hugh Jackman', 'Patrick Stewart', 'Dafne Keen']
# year = 2017
# genres = ['Action', 'Drama', 'Sci-Fi']
# description = In a future where mutants are nearly extinct, an elderly and weary Logan leads a quiet life. But when Laura, a mutant child pursued by scientists, comes to him for help, he must get her to safety.
# duration = 137
#
# rank = 216
# title = В центре внимания
# rating = 8.1
# vote count = 494736
# director(s) = ['Tom McCarthy']
# writer(s) = ['Josh Singer', 'Tom McCarthy']
# star(s) = ['Mark Ruffalo', 'Michael Keaton', 'Rachel McAdams']
# year = 2015
# genres = ['Biography', 'Crime', 'Drama']
# description = The true story of how the Boston Globe uncovered the massive scandal of child molestation and cover-up within the local Catholic Archdiocese, shaking the entire Catholic Church to its core.
# duration = 129
#
# rank = 217
# title = Взвод
# rating = 8.1
# vote count = 432588
# director(s) = ['Oliver Stone']
# writer(s) = ['Oliver Stone']
# star(s) = ['Charlie Sheen', 'Tom Berenger', 'Willem Dafoe']
# year = 1986
# genres = ['Drama', 'War']
# description = Chris Taylor, a neophyte recruit in Vietnam, finds himself caught in a battle of wills between two sergeants, one good and the other evil. A shrewd examination of the brutality of war and the duality of man in conflict.
# duration = 120
#
# rank = 218
# title = Страсти Жанны д'Арк
# rating = 8.1
# vote count = 59396
# director(s) = ['Carl Theodor Dreyer']
# writer(s) = ['Joseph Delteil', 'Carl Theodor Dreyer']
# star(s) = ['Maria Falconetti', 'Eugene Silvain', 'André Berley']
# year = 1928
# genres = ['Biography', 'Drama', 'History']
# description = In 1431, Jeanne d'Arc is placed on trial on charges of heresy. The ecclesiastical jurists attempt to force Jeanne to recant her claims of holy visions.
# duration = 110
#
# rank = 219
# title = Терминатор
# rating = 8.1
# vote count = 909890
# director(s) = ['James Cameron']
# writer(s) = ['James Cameron', 'Gale Anne Hurd', 'William Wisher']
# star(s) = ['Arnold Schwarzenegger', 'Linda Hamilton', 'Michael Biehn']
# year = 1984
# genres = ['Action', 'Sci-Fi']
# description = A human soldier is sent from 2029 to 1984 to stop an almost indestructible cyborg killing machine, sent from the same year, which has been programmed to execute a young woman whose unborn son is the key to humanity's future salvation.
# duration = 107
#
# rank = 220
# title = Перед закатом
# rating = 8.1
# vote count = 282822
# director(s) = ['Richard Linklater']
# writer(s) = ['Richard Linklater', 'Julie Delpy', 'Ethan Hawke']
# star(s) = ['Ethan Hawke', 'Julie Delpy', 'Vernon Dobtcheff']
# year = 2004
# genres = ['Drama', 'Romance']
# description = Nine years after Jesse and Celine first met, they encounter each other again on the French leg of Jesse's book tour.
# duration = 80
#
# rank = 221
# title = Да прольётся свет
# rating = 8.7
# vote count = 213662
# director(s) = ['T.J. Gnanavel']
# writer(s) = ['T.J. Gnanavel', 'Rajendra Sapre']
# star(s) = ['Suriya', 'Lijo Mol Jose', 'Manikandan K.']
# year = 2021
# genres = ['Crime', 'Drama', 'Mystery']
# description = When a tribal man is arrested for a case of alleged theft, his wife turns to a human-rights lawyer to help bring justice.
# duration = 164
#
# rank = 222
# title = Гонка
# rating = 8.1
# vote count = 505118
# director(s) = ['Ron Howard']
# writer(s) = ['Peter Morgan']
# star(s) = ['Daniel Brühl', 'Chris Hemsworth', 'Olivia Wilde']
# year = 2013
# genres = ['Action', 'Biography', 'Drama']
# description = The merciless 1970s rivalry between Formula One rivals James Hunt and Niki Lauda.
# duration = 123
#
# rank = 223
# title = Телесеть
# rating = 8.1
# vote count = 167638
# director(s) = ['Sidney Lumet']
# writer(s) = ['Paddy Chayefsky']
# star(s) = ['Faye Dunaway', 'William Holden', 'Peter Finch']
# year = 1976
# genres = ['Drama']
# description = A television network cynically exploits a deranged former anchor's ravings and revelations about the news media for its own profit, but finds that his message may be difficult to control.
# duration = 121
#
# rank = 224
# title = Изгоняющий дьявола
# rating = 8.1
# vote count = 447070
# director(s) = ['William Friedkin']
# writer(s) = ['William Peter Blatty']
# star(s) = ['Ellen Burstyn', 'Max von Sydow', 'Linda Blair']
# year = 1973
# genres = ['Horror']
# description = When a young girl is possessed by a mysterious entity, her mother seeks the help of two Catholic priests to save her life.
# duration = 122
#
# rank = 225
# title = Лучшие годы нашей жизни
# rating = 8.1
# vote count = 69237
# director(s) = ['William Wyler']
# writer(s) = ['Robert E. Sherwood', 'MacKinlay Kantor']
# star(s) = ['Myrna Loy', 'Dana Andrews', 'Fredric March']
# year = 1946
# genres = ['Drama', 'Romance', 'War']
# description = Three World War II veterans, two of them traumatized or disabled, return home to the American midwest to discover that they and their families have been irreparably changed.
# duration = 170
#
# rank = 226
# title = Останься со мной
# rating = 8.1
# vote count = 432889
# director(s) = ['Rob Reiner']
# writer(s) = ['Stephen King', 'Raynold Gideon', 'Bruce A. Evans']
# star(s) = ['Wil Wheaton', 'River Phoenix', 'Corey Feldman']
# year = 1986
# genres = ['Adventure', 'Comedy', 'Drama']
# description = After the death of his childhood best friend, a writer recounts a childhood journey with his friends to find the body of a missing boy.
# duration = 89
#
# rank = 227
# title = Ненависть
# rating = 8.1
# vote count = 191076
# director(s) = ['Mathieu Kassovitz']
# writer(s) = ['Mathieu Kassovitz']
# star(s) = ['Vincent Cassel', 'Hubert Koundé', 'Saïd Taghmaoui']
# year = 1995
# genres = ['Crime', 'Drama']
# description = 24 hours in the lives of three young men in the French suburbs the day after a violent riot.
# duration = 98
#
# rank = 228
# title = Пираты Карибского моря: Проклятие Чёрной жемчужины
# rating = 8.1
# vote count = 1188277
# director(s) = ['Gore Verbinski']
# writer(s) = ['Ted Elliott', 'Terry Rossio', 'Stuart Beattie']
# star(s) = ['Johnny Depp', 'Geoffrey Rush', 'Orlando Bloom']
# year = 2003
# genres = ['Action', 'Adventure', 'Fantasy']
# description = Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor's daughter, from Jack's former pirate allies, who are now undead.
# duration = 143
#
# rank = 229
# title = Волшебник страны Оз
# rating = 8.1
# vote count = 421784
# director(s) = ['Victor Fleming', 'King Vidor']
# writer(s) = ['Noel Langley', 'Florence Ryerson', 'Edgar Allan Woolf']
# star(s) = ['Judy Garland', 'Frank Morgan', 'Ray Bolger']
# year = 1939
# genres = ['Adventure', 'Family', 'Fantasy']
# description = Young Dorothy Gale and her dog Toto are swept away by a tornado from their Kansas farm to the magical Land of Oz, and embark on a quest with three new friends to see the Wizard, who can return her to her home and fulfill the others' wishes.
# duration = 102
#
# rank = 230
# title = Суперсемейка
# rating = 8.0
# vote count = 791053
# director(s) = ['Brad Bird']
# writer(s) = ['Brad Bird']
# star(s) = ['Craig T. Nelson', 'Samuel L. Jackson', 'Holly Hunter']
# year = 2004
# genres = ['Animation', 'Action', 'Adventure']
# description = While trying to lead a quiet suburban life, a family of undercover superheroes are forced into action to save the world.
# duration = 115
#
# rank = 231
# title = В диких условиях
# rating = 8.1
# vote count = 649227
# director(s) = ['Sean Penn']
# writer(s) = ['Sean Penn', 'Jon Krakauer']
# star(s) = ['Emile Hirsch', 'Vince Vaughn', 'Catherine Keener']
# year = 2007
# genres = ['Adventure', 'Biography', 'Drama']
# description = After graduating from Emory University, top student and athlete Christopher McCandless abandons his possessions, gives his entire $24,000 savings account to charity and hitchhikes to Alaska to live in the wilderness. Along the way, Christopher encounters a series of characters that shape his life.
# duration = 148
#
# rank = 232
# title = Хатико: самый верный друг
# rating = 8.1
# vote count = 305068
# director(s) = ['Lasse Hallström']
# writer(s) = ['Stephen P. Lindsey', 'Kaneto Shindô']
# star(s) = ['Richard Gere', 'Joan Allen', 'Cary-Hiroyuki Tagawa']
# year = 2009
# genres = ['Biography', 'Drama', 'Family']
# description = A college professor bonds with an abandoned dog he takes into his home.
# duration = 93
#
# rank = 233
# title = Служанка
# rating = 8.1
# vote count = 166833
# director(s) = ['Park Chan-wook']
# writer(s) = ['Sarah Waters', 'Chung Seo-kyung', 'Park Chan-wook']
# star(s) = ['Kim Min-hee', 'Ha Jung-woo', 'Cho Jin-woong']
# year = 2016
# genres = ['Drama', 'Romance', 'Thriller']
# description = A woman is hired as a handmaiden to a Japanese heiress, but secretly she is involved in a plot to defraud her.
# duration = 145
#
# rank = 234
# title = To Be or Not to Be
# rating = 8.1
# vote count = 41795
# director(s) = ['Ernst Lubitsch']
# writer(s) = ['Melchior Lengyel', 'Edwin Justus Mayer', 'Ernst Lubitsch']
# star(s) = ['Carole Lombard', 'Jack Benny', 'Robert Stack']
# year = 1942
# genres = ['Comedy', 'Romance', 'War']
# description = During the Nazi occupation of Poland, an acting troupe becomes embroiled in a Polish soldier's efforts to track down a German spy.
# duration = 99
#
# rank = 235
# title = Мой отец и мой сын
# rating = 8.2
# vote count = 91019
# director(s) = ['Çagan Irmak']
# writer(s) = ['Çagan Irmak']
# star(s) = ['Çetin Tekindor', 'Fikret Kuskan', 'Hümeyra']
# year = 2005
# genres = ['Drama', 'Family']
# description = The family of a left-wing journalist is torn apart after the military coup of Turkey in 1980.
# duration = 112
#
# rank = 236
# title = День сурка
# rating = 8.0
# vote count = 671268
# director(s) = ['Harold Ramis']
# writer(s) = ['Danny Rubin', 'Harold Ramis']
# star(s) = ['Bill Murray', 'Andie MacDowell', 'Chris Elliott']
# year = 1993
# genres = ['Comedy', 'Drama', 'Fantasy']
# description = A narcissistic, self-centered weatherman finds himself in a time loop on Groundhog Day.
# duration = 101
#
# rank = 237
# title = La battaglia di Algeri
# rating = 8.1
# vote count = 64518
# director(s) = ['Gillo Pontecorvo']
# writer(s) = ['Franco Solinas', 'Gillo Pontecorvo']
# star(s) = ['Brahim Hadjadj', 'Jean Martin', 'Yacef Saadi']
# year = 1966
# genres = ['Drama', 'War']
# description = In the 1950s, fear and violence escalate as the people of Algiers fight for independence from the French government.
# duration = 121
#
# rank = 238
# title = Гроздья гнева
# rating = 8.1
# vote count = 98616
# director(s) = ['John Ford']
# writer(s) = ['Nunnally Johnson', 'John Steinbeck']
# star(s) = ['Henry Fonda', 'Jane Darwell', 'John Carradine']
# year = 1940
# genres = ['Drama']
# description = An Oklahoma family, driven off their farm by the poverty and hopelessness of the Dust Bowl, joins the westward migration to California, suffering the misfortunes of the homeless in the Great Depression.
# duration = 129
#
# rank = 239
# title = Звуки музыки
# rating = 8.1
# vote count = 254205
# director(s) = ['Robert Wise']
# writer(s) = ['Georg Hurdalek', 'Howard Lindsay', 'Russel Crouse']
# star(s) = ['Julie Andrews', 'Christopher Plummer', 'Eleanor Parker']
# year = 1965
# genres = ['Biography', 'Drama', 'Family']
# description = A young novice is sent by her convent in 1930s Austria to become a governess to the seven children of a widowed naval officer.
# duration = 172
#
# rank = 240
# title = Сука любовь
# rating = 8.1
# vote count = 250339
# director(s) = ['Alejandro G. Iñárritu']
# writer(s) = ['Guillermo Arriaga']
# star(s) = ['Emilio Echevarría', 'Gael García Bernal', 'Goya Toledo']
# year = 2000
# genres = ['Drama', 'Thriller']
# description = A horrific car accident connects three stories, each involving characters dealing with loss, regret, and life's harsh realities, all in the name of love.
# duration = 154
#
# rank = 241
# title = Ребекка
# rating = 8.1
# vote count = 144487
# director(s) = ['Alfred Hitchcock']
# writer(s) = ['Daphne Du Maurier', 'Robert E. Sherwood', 'Joan Harrison']
# star(s) = ['Laurence Olivier', 'Joan Fontaine', 'George Sanders']
# year = 1940
# genres = ['Drama', 'Film-Noir', 'Mystery']
# description = A self-conscious woman juggles adjusting to her new role as an aristocrat's wife and avoiding being intimidated by his first wife's spectral presence.
# duration = 130
#
# rank = 242
# title = Хладнокровный Люк
# rating = 8.1
# vote count = 186254
# director(s) = ['Stuart Rosenberg']
# writer(s) = ['Donn Pearce', 'Frank Pierson', 'Hal Dresner']
# star(s) = ['Paul Newman', 'George Kennedy', 'Strother Martin']
# year = 1967
# genres = ['Crime', 'Drama']
# description = A laid-back Southern man is sentenced to two years in a rural prison, but refuses to conform.
# duration = 127
#
# rank = 243
# title = Стальной гигант
# rating = 8.1
# vote count = 220625
# director(s) = ['Brad Bird']
# writer(s) = ['Tim McCanlies', 'Brad Bird', 'Ted Hughes']
# star(s) = ['Eli Marienthal', 'Harry Connick Jr.', 'Jennifer Aniston']
# year = 1999
# genres = ['Animation', 'Action', 'Adventure']
# description = A young boy befriends a giant robot from outer space that a paranoid government agent wants to destroy.
# duration = 86
#
# rank = 244
# title = Прислуга
# rating = 8.1
# vote count = 484684
# director(s) = ['Tate Taylor']
# writer(s) = ['Tate Taylor', 'Kathryn Stockett']
# star(s) = ['Viola Davis', 'Emma Stone', 'Octavia Spencer']
# year = 2011
# genres = ['Drama']
# description = An aspiring author during the civil rights movement of the 1960s decides to write a book detailing the African American maids' point of view on the white families for which they work, and the hardships they go through on a daily basis.
# duration = 146
#
# rank = 245
# title = Это случилось однажды ночью
# rating = 8.1
# vote count = 110287
# director(s) = ['Frank Capra']
# writer(s) = ['Robert Riskin', 'Samuel Hopkins Adams']
# star(s) = ['Clark Gable', 'Claudette Colbert', 'Walter Connolly']
# year = 1934
# genres = ['Comedy', 'Romance']
# description = A renegade reporter trailing a young runaway heiress for a big story joins her on a bus heading from Florida to New York, and they end up stuck with each other when the bus leaves them behind at one of the stops.
# duration = 105
#
# rank = 246
# title = Pather Panchali
# rating = 8.2
# vote count = 37375
# director(s) = ['Satyajit Ray']
# writer(s) = ['Bibhutibhushan Bandyopadhyay', 'Satyajit Ray']
# star(s) = ['Kanu Bannerjee', 'Karuna Bannerjee', 'Subir Banerjee']
# year = 1955
# genres = ['Drama']
# description = Impoverished priest Harihar Ray, dreaming of a better life for himself and his family, leaves his rural Bengal village in search of work.
# duration = 125
#
# rank = 247
# title = Четыреста ударов
# rating = 8.1
# vote count = 125951
# director(s) = ['François Truffaut']
# writer(s) = ['François Truffaut', 'Marcel Moussy']
# star(s) = ['Jean-Pierre Léaud', 'Albert Rémy', 'Claire Maurier']
# year = 1959
# genres = ['Crime', 'Drama']
# description = A young boy, left without attention, delves into a life of petty crime.
# duration = 99
#
# rank = 248
# title = Аладдин
# rating = 8.0
# vote count = 456107
# director(s) = ['Ron Clements', 'John Musker']
# writer(s) = ['Ron Clements', 'John Musker', 'Ted Elliott']
# star(s) = ['Scott Weinger', 'Robin Williams', 'Linda Larkin']
# year = 1992
# genres = ['Animation', 'Adventure', 'Comedy']
# description = A kind-hearted street urchin and a power-hungry Grand Vizier vie for a magic lamp that has the power to make their deepest wishes come true.
# duration = 90
#
# rank = 249
# title = Танцующий с волками
# rating = 8.0
# vote count = 285364
# director(s) = ['Kevin Costner']
# writer(s) = ['Michael Blake']
# star(s) = ['Kevin Costner', 'Mary McDonnell', 'Graham Greene']
# year = 1990
# genres = ['Adventure', 'Drama', 'Western']
# description = Lieutenant John Dunbar, assigned to a remote western Civil War outpost, finds himself engaging with a neighbouring Sioux settlement, causing him to question his own purpose.
# duration = 181
#
# rank = 250
# title = Житие Брайана по Монти Пайтон
# rating = 8.0
# vote count = 418603
# director(s) = ['Terry Jones']
# writer(s) = ['Graham Chapman', 'John Cleese', 'Terry Gilliam']
# star(s) = ['Graham Chapman', 'John Cleese', 'Michael Palin']
# year = 1979
# genres = ['Comedy']
# description = Born on the original Christmas in the stable next door to Jesus Christ, Brian of Nazareth spends his life being mistaken for a messiah.
# duration = 94

# %%
for movie in movies_res[:10]:
    print(movie.rating_dist)
# Out:
# {1: 41912, 2: 5267, 3: 5733, 4: 7809, 5: 16299, 6: 31544, 7: 105498, 8: 333308, 9: 730016, 10: 1557486}
# {1: 41674, 2: 6940, 3: 7517, 4: 10168, 5: 20005, 6: 36366, 7: 96614, 8: 245765, 9: 491483, 10: 1019199}
# {1: 39813, 2: 8375, 3: 9212, 4: 12952, 5: 26678, 6: 56512, 7: 161052, 8: 425502, 9: 797123, 10: 1278942}
# {1: 22875, 2: 4542, 3: 5130, 4: 7255, 5: 15126, 6: 30895, 7: 83492, 8: 208343, 9: 385302, 10: 577975}
# {1: 9869, 2: 1807, 3: 2150, 4: 3457, 5: 7585, 6: 18347, 7: 57016, 8: 159799, 9: 272715, 10: 313183}
# {1: 22002, 2: 4880, 3: 5245, 4: 7100, 5: 14947, 6: 30823, 7: 94246, 8: 256254, 9: 450325, 10: 538626}
# {1: 32815, 2: 7324, 3: 8964, 4: 12188, 5: 24983, 6: 50977, 7: 134504, 8: 313592, 9: 510324, 10: 845579}
# {1: 29744, 2: 10252, 3: 12010, 4: 16647, 5: 31705, 6: 62983, 7: 173121, 8: 407690, 9: 647734, 10: 782534}
# {1: 30492, 2: 7758, 3: 9353, 4: 12534, 5: 26036, 6: 54257, 7: 155284, 8: 372826, 9: 544105, 10: 755707}
# {1: 11497, 2: 2352, 3: 2934, 4: 4613, 5: 10142, 6: 22246, 7: 69996, 8: 163417, 9: 229560, 10: 281520}

# %%
save_object(movies_res, 'movie_list.pkl')

# %% [markdown]
# #### Создание таблиц

# %%
conn = sqlite3.connect('movie_db')

# %%
sql_create_movie_table = '''
    CREATE TABLE IF NOT EXISTS Movie (
        id INTEGER PRIMARY KEY,
        rank INTEGER UNIQUE,
        rating REAL NOT NULL,
        vote_count INTEGER NOT NULL,
        year INTEGER NOT NULL,
        title TEXT NOT NULL,
        description TEXT,
        duration INTEGER NOT NULL
    );'''

# %%
sql_create_person_table = '''
    CREATE TABLE IF NOT EXISTS Person (
        id INTEGER PRIMARY KEY,
        name TEXT UNIQUE NOT NULL
    );'''

# %%
sql_create_genre_table = '''
    CREATE TABLE IF NOT EXISTS Genre (
        id INTEGER PRIMARY KEY,
        name TEXT UNIQUE NOT NULL
    );'''

# %%
sql_create_movie_director_table = '''
    CREATE TABLE IF NOT EXISTS MovieDirector (
        movie_id INTEGER NOT NULL,
        director_id INTEGER NOT NULL,
        UNIQUE(movie_id, director_id),
        FOREIGN KEY(movie_id) REFERENCES Movie(id),
        FOREIGN KEY(director_id) REFERENCES Person(id)
    );'''

# %%
sql_create_movie_writer_table = '''
    CREATE TABLE IF NOT EXISTS MovieWriter (
        movie_id INTEGER NOT NULL,
        writer_id INTEGER NOT NULL,
        UNIQUE(movie_id, writer_id),
        FOREIGN KEY(movie_id) REFERENCES Movie(id),
        FOREIGN KEY(writer_id) REFERENCES Person(id)
    );'''

# %%
sql_create_movie_star_table = '''
    CREATE TABLE IF NOT EXISTS MovieStar (
        movie_id INTEGER NOT NULL,
        star_id INTEGER NOT NULL,
        UNIQUE(movie_id, star_id),
        FOREIGN KEY(movie_id) REFERENCES Movie(id),
        FOREIGN KEY(star_id) REFERENCES Person(id)
    );'''

# %%
sql_create_movie_genre_table = '''
    CREATE TABLE IF NOT EXISTS MovieGenre (
        movie_id INTEGER NOT NULL,
        genre_id INTEGER NOT NULL,
        UNIQUE(movie_id, genre_id),
        FOREIGN KEY(movie_id) REFERENCES Movie(id),
        FOREIGN KEY(genre_id) REFERENCES Genre(id)
    );'''

# %%
sql_create_movie_rating_dist_table = '''
    CREATE TABLE IF NOT EXISTS MovieRatingDist (
        movie_id INTEGER NOT NULL,
        rating INTEGER,
        vote_count INTEGER NOT NULL,
        UNIQUE(movie_id, rating)
    );'''

# %%
cursor = conn.cursor()

# %%
cursor.execute(sql_create_movie_table)
cursor.execute(sql_create_person_table)
cursor.execute(sql_create_genre_table)
cursor.execute(sql_create_movie_director_table)
cursor.execute(sql_create_movie_writer_table)
cursor.execute(sql_create_movie_star_table)
cursor.execute(sql_create_movie_genre_table)
cursor.execute(sql_create_movie_rating_dist_table)

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('Movie',), ('Person',), ('Genre',), ('MovieDirector',), ('MovieWriter',), ('MovieStar',), ('MovieGenre',), ('MovieRatingDist',)]

# %% [markdown]
# #### Заполнение таблиц

# %%
genre_set = set()
genre_list = []

person_set = set()
person_list = []

# %%
for movie in movies_res:
    for d in movie.directors:
        if d not in person_set:
            person_set.add(d)
            person_list.append(d)
    for w in movie.writers:
        if w not in person_set:
            person_set.add(w)
            person_list.append(w)
    for s in movie.stars:
        if s not in person_set:
            person_set.add(s)
            person_list.append(s)
    for g in movie.genres:
        if g not in genre_set:
            genre_set.add(g)
            genre_list.append(g)

# %%
person_list
# Out:
# ['Frank Darabont',
#  'Stephen King',
#  'Tim Robbins',
#  'Morgan Freeman',
#  'Bob Gunton',
#  'Francis Ford Coppola',
#  'Mario Puzo',
#  'Marlon Brando',
#  'Al Pacino',
#  'James Caan',
#  'Christopher Nolan',
#  'Jonathan Nolan',
#  'David S. Goyer',
#  'Christian Bale',
#  'Heath Ledger',
#  'Aaron Eckhart',
#  'Robert De Niro',
#  'Robert Duvall',
#  'Sidney Lumet',
#  'Reginald Rose',
#  'Henry Fonda',
#  'Lee J. Cobb',
#  'Martin Balsam',
#  'Steven Spielberg',
#  'Thomas Keneally',
#  'Steven Zaillian',
#  'Liam Neeson',
#  'Ralph Fiennes',
#  'Ben Kingsley',
#  'Peter Jackson',
#  'J.R.R. Tolkien',
#  'Fran Walsh',
#  'Philippa Boyens',
#  'Elijah Wood',
#  'Viggo Mortensen',
#  'Ian McKellen',
#  'Quentin Tarantino',
#  'Roger Avary',
#  'John Travolta',
#  'Uma Thurman',
#  'Samuel L. Jackson',
#  'Orlando Bloom',
#  'Sergio Leone',
#  'Luciano Vincenzoni',
#  'Agenore Incrocci',
#  'Clint Eastwood',
#  'Eli Wallach',
#  'Lee Van Cleef',
#  'Robert Zemeckis',
#  'Winston Groom',
#  'Eric Roth',
#  'Tom Hanks',
#  'Robin Wright',
#  'Gary Sinise',
#  'David Fincher',
#  'Chuck Palahniuk',
#  'Jim Uhls',
#  'Brad Pitt',
#  'Edward Norton',
#  'Meat Loaf',
#  'Leonardo DiCaprio',
#  'Joseph Gordon-Levitt',
#  'Elliot Page',
#  'Irvin Kershner',
#  'Leigh Brackett',
#  'Lawrence Kasdan',
#  'George Lucas',
#  'Mark Hamill',
#  'Harrison Ford',
#  'Carrie Fisher',
#  'Lana Wachowski',
#  'Lilly Wachowski',
#  'Keanu Reeves',
#  'Laurence Fishburne',
#  'Carrie-Anne Moss',
#  'Martin Scorsese',
#  'Nicholas Pileggi',
#  'Ray Liotta',
#  'Joe Pesci',
#  'Milos Forman',
#  'Lawrence Hauben',
#  'Bo Goldman',
#  'Ken Kesey',
#  'Jack Nicholson',
#  'Louise Fletcher',
#  'Michael Berryman',
#  'Andrew Kevin Walker',
#  'Kevin Spacey',
#  'Frank Capra',
#  'Frances Goodrich',
#  'Albert Hackett',
#  'James Stewart',
#  'Donna Reed',
#  'Lionel Barrymore',
#  'Akira Kurosawa',
#  'Shinobu Hashimoto',
#  'Hideo Oguni',
#  'Toshirô Mifune',
#  'Takashi Shimura',
#  'Keiko Tsushima',
#  'Matthew McConaughey',
#  'Anne Hathaway',
#  'Jessica Chastain',
#  'Jonathan Demme',
#  'Thomas Harris',
#  'Ted Tally',
#  'Jodie Foster',
#  'Anthony Hopkins',
#  'Scott Glenn',
#  'Robert Rodat',
#  'Matt Damon',
#  'Tom Sizemore',
#  'Fernando Meirelles',
#  'Kátia Lund',
#  'Paulo Lins',
#  'Bráulio Mantovani',
#  'Alexandre Rodrigues',
#  'Leandro Firmino',
#  'Matheus Nachtergaele',
#  'Roberto Benigni',
#  'Vincenzo Cerami',
#  'Nicoletta Braschi',
#  'Giorgio Cantarini',
#  'Michael Clarke Duncan',
#  'David Morse',
#  'Joaquim Dos Santos',
#  'Kemp Powers',
#  'Justin K. Thompson',
#  'Phil Lord',
#  'Christopher Miller',
#  'Dave Callaham',
#  'Shameik Moore',
#  'Hailee Steinfeld',
#  'Brian Tyree Henry',
#  'James Cameron',
#  'William Wisher',
#  'Arnold Schwarzenegger',
#  'Linda Hamilton',
#  'Edward Furlong',
#  'Bob Gale',
#  'Michael J. Fox',
#  'Christopher Lloyd',
#  'Lea Thompson',
#  'Hayao Miyazaki',
#  'Daveigh Chase',
#  'Suzanne Pleshette',
#  'Miyu Irino',
#  'Roman Polanski',
#  'Ronald Harwood',
#  'Wladyslaw Szpilman',
#  'Adrien Brody',
#  'Thomas Kretschmann',
#  'Frank Finlay',
#  'Bong Joon Ho',
#  'Han Jin-won',
#  'Song Kang-ho',
#  'Lee Sun-kyun',
#  'Cho Yeo-jeong',
#  'Alfred Hitchcock',
#  'Joseph Stefano',
#  'Robert Bloch',
#  'Anthony Perkins',
#  'Janet Leigh',
#  'Vera Miles',
#  'Ridley Scott',
#  'David Franzoni',
#  'John Logan',
#  'William Nicholson',
#  'Russell Crowe',
#  'Joaquin Phoenix',
#  'Connie Nielsen',
#  'Roger Allers',
#  'Rob Minkoff',
#  'Irene Mecchi',
#  'Jonathan Roberts',
#  'Linda Woolverton',
#  'Matthew Broderick',
#  'Jeremy Irons',
#  'James Earl Jones',
#  'Luc Besson',
#  'Jean Reno',
#  'Gary Oldman',
#  'Natalie Portman',
#  'Tony Kaye',
#  'David McKenna',
#  "Beverly D'Angelo",
#  'William Monahan',
#  'Alan Mak',
#  'Felix Chong',
#  'Damien Chazelle',
#  'Miles Teller',
#  'J.K. Simmons',
#  'Melissa Benoist',
#  'Christopher Priest',
#  'Hugh Jackman',
#  'Scarlett Johansson',
#  'Isao Takahata',
#  'Akiyuki Nosaka',
#  'Tsutomu Tatsumi',
#  'Ayano Shiraishi',
#  'Akemi Yamaguchi',
#  'Bryan Singer',
#  'Christopher McQuarrie',
#  'Gabriel Byrne',
#  'Chazz Palminteri',
#  'Masaki Kobayashi',
#  'Yasuhiko Takiguchi',
#  'Tatsuya Nakadai',
#  'Akira Ishihama',
#  'Shima Iwashita',
#  'Michael Curtiz',
#  'Julius J. Epstein',
#  'Philip G. Epstein',
#  'Howard Koch',
#  'Humphrey Bogart',
#  'Ingrid Bergman',
#  'Paul Henreid',
#  'Olivier Nakache',
#  'Éric Toledano',
#  'Philippe Pozzo di Borgo',
#  'François Cluzet',
#  'Omar Sy',
#  'Anne Le Ny',
#  'Charles Chaplin',
#  'Paulette Goddard',
#  'Henry Bergman',
#  'Giuseppe Tornatore',
#  'Vanna Paoli',
#  'Philippe Noiret',
#  'Enzo Cannavale',
#  'Antonella Attili',
#  'John Michael Hayes',
#  'Cornell Woolrich',
#  'Grace Kelly',
#  'Wendell Corey',
#  'Sergio Donati',
#  'Dario Argento',
#  'Charles Bronson',
#  'Claudia Cardinale',
#  "Dan O'Bannon",
#  'Ronald Shusett',
#  'Sigourney Weaver',
#  'Tom Skerritt',
#  'John Hurt',
#  'Harry Carr',
#  'Harry Crocker',
#  'Virginia Cherrill',
#  'Florence Lee',
#  'John Milius',
#  'Michael Herr',
#  'Martin Sheen',
#  'Jamie Foxx',
#  'Christoph Waltz',
#  'Guy Pearce',
#  'Joe Pantoliano',
#  'Philip Kaufman',
#  'Karen Allen',
#  'Paul Freeman',
#  'Andrew Stanton',
#  'Pete Docter',
#  'Jim Reardon',
#  'Ben Burtt',
#  'Elissa Knight',
#  'Jeff Garlin',
#  'Florian Henckel von Donnersmarck',
#  'Ulrich Mühe',
#  'Martina Gedeck',
#  'Sebastian Koch',
#  'Billy Wilder',
#  'Charles Brackett',
#  'D.M. Marshman Jr.',
#  'William Holden',
#  'Gloria Swanson',
#  'Erich von Stroheim',
#  'Stanley Kubrick',
#  'Calder Willingham',
#  'Jim Thompson',
#  'Kirk Douglas',
#  'Ralph Meeker',
#  'Adolphe Menjou',
#  'Anthony Russo',
#  'Joe Russo',
#  'Christopher Markus',
#  'Stephen McFeely',
#  'Stan Lee',
#  'Robert Downey Jr.',
#  'Chris Hemsworth',
#  'Mark Ruffalo',
#  'Diane Johnson',
#  'Shelley Duvall',
#  'Danny Lloyd',
#  'Bob Persichetti',
#  'Peter Ramsey',
#  'Rodney Rothman',
#  'Jake Johnson',
#  'Agatha Christie',
#  'Harry Kurnitz',
#  'Tyrone Power',
#  'Marlene Dietrich',
#  'Charles Laughton',
#  'Jack Oakie',
#  'David Giler',
#  'Walter Hill',
#  'Michael Biehn',
#  'Carrie Henn',
#  'Kai Bird',
#  'Martin Sherwin',
#  'Cillian Murphy',
#  'Emily Blunt',
#  'Diane Kruger',
#  'Eli Roth',
#  'Tom Hardy',
#  'Sam Mendes',
#  'Alan Ball',
#  'Annette Bening',
#  'Thora Birch',
#  'Terry Southern',
#  'Peter George',
#  'Peter Sellers',
#  'George C. Scott',
#  'Sterling Hayden',
#  'Park Chan-wook',
#  'Garon Tsuchiya',
#  'Nobuaki Minegishi',
#  'Choi Min-sik',
#  'Yoo Ji-tae',
#  'Kang Hye-jeong',
#  'Lee Unkrich',
#  'Adrian Molina',
#  'Jason Katz',
#  'Matthew Aldrich',
#  'Anthony Gonzalez',
#  'Gael García Bernal',
#  'Benjamin Bratt',
#  'Peter Shaffer',
#  'Zdenek Mahler',
#  'F. Murray Abraham',
#  'Tom Hulce',
#  'Elizabeth Berridge',
#  'John Lasseter',
#  'Tim Allen',
#  'Don Rickles',
#  'Wolfgang Petersen',
#  'Lothar G. Buchheim',
#  'Jürgen Prochnow',
#  'Herbert Grönemeyer',
#  'Klaus Wennemann',
#  'Mel Gibson',
#  'Randall Wallace',
#  'Sophie Marceau',
#  'Patrick McGoohan',
#  'Chris Evans',
#  'Todd Phillips',
#  'Scott Silver',
#  'Bob Kane',
#  'Zazie Beetz',
#  'Neil Gaiman',
#  'Yôji Matsuda',
#  'Yuriko Ishida',
#  'Yûko Tanaka',
#  'Gus Van Sant',
#  'Ben Affleck',
#  'Robin Williams',
#  'Makoto Shinkai',
#  'Clark Cheng',
#  'Ryunosuke Kamiki',
#  'Mone Kamishiraishi',
#  'Ryo Narita',
#  'Harry Grey',
#  'Leonardo Benvenuti',
#  'Piero De Bernardi',
#  'James Woods',
#  'Elizabeth McGovern',
#  'Rajkumar Hirani',
#  'Abhijat Joshi',
#  'Vidhu Vinod Chopra',
#  'Aamir Khan',
#  'Madhavan',
#  'Mona Singh',
#  'Ryûzô Kikushima',
#  'Eijirô Hisaita',
#  'Yutaka Sada',
#  'Stanley Donen',
#  'Gene Kelly',
#  'Betty Comden',
#  'Adolph Green',
#  "Donald O'Connor",
#  'Debbie Reynolds',
#  'Nadine Labaki',
#  'Jihad Hojeily',
#  'Michelle Keserwany',
#  'Zain Al Rafeea',
#  'Yordanos Shiferaw',
#  'Boluwatife Treasure Bankole',
#  'Darren Aronofsky',
#  'Hubert Selby Jr.',
#  'Ellen Burstyn',
#  'Jared Leto',
#  'Jennifer Connelly',
#  'Elem Klimov',
#  'Ales Adamovich',
#  'Aleksey Kravchenko',
#  'Olga Mironova',
#  'Liubomiras Laucevicius',
#  'Joan Cusack',
#  'Richard Marquand',
#  'Michel Gondry',
#  'Charlie Kaufman',
#  'Pierre Bismuth',
#  'Jim Carrey',
#  'Kate Winslet',
#  'Tom Wilkinson',
#  'Thomas Vinterberg',
#  'Tobias Lindholm',
#  'Mads Mikkelsen',
#  'Thomas Bo Larsen',
#  'Annika Wedderkopp',
#  'Arthur C. Clarke',
#  'Keir Dullea',
#  'Gary Lockwood',
#  'William Sylvester',
#  'Harvey Keitel',
#  'Tim Roth',
#  'Michael Madsen',
#  'Nobuo Kaneko',
#  "Shin'ichi Himori",
#  'David Lean',
#  'Robert Bolt',
#  'Michael Wilson',
#  "Peter O'Toole",
#  'Alec Guinness',
#  'Anthony Quinn',
#  'I.A.L. Diamond',
#  'Jack Lemmon',
#  'Shirley MacLaine',
#  'Fred MacMurray',
#  'Orson Welles',
#  'Herman J. Mankiewicz',
#  'John Houseman',
#  'Joseph Cotten',
#  'Dorothy Comingore',
#  'Fritz Lang',
#  'Thea von Harbou',
#  'Egon Jacobsohn',
#  'Peter Lorre',
#  'Ellen Widmann',
#  'Inge Landgut',
#  'Ernest Lehman',
#  'Cary Grant',
#  'Eva Marie Saint',
#  'James Mason',
#  'Alec Coppel',
#  'Samuel A. Taylor',
#  'Pierre Boileau',
#  'Kim Novak',
#  'Barbara Bel Geddes',
#  'Raymond Chandler',
#  'James M. Cain',
#  'Barbara Stanwyck',
#  'Edward G. Robinson',
#  'Brian De Palma',
#  'Oliver Stone',
#  'Howard Hawks',
#  'Ben Hecht',
#  'Michelle Pfeiffer',
#  'Steven Bauer',
#  'Jean-Pierre Jeunet',
#  'Guillaume Laurant',
#  'Audrey Tautou',
#  'Mathieu Kassovitz',
#  'Rufus',
#  'Gustav Hasford',
#  'Matthew Modine',
#  'R. Lee Ermey',
#  "Vincent D'Onofrio",
#  'Denis Villeneuve',
#  'Wajdi Mouawad',
#  'Valérie Beaugrand-Champagne',
#  'Lubna Azabal',
#  'Mélissa Désormeaux-Poulin',
#  'Maxim Gaudette',
#  'Anthony Burgess',
#  'Malcolm McDowell',
#  'Patrick Magee',
#  'Michael Bates',
#  'Michael Mann',
#  'Val Kilmer',
#  'Bob Peterson',
#  'Tom McCarthy',
#  'Edward Asner',
#  'Jordan Nagai',
#  'John Ratzenberger',
#  'Robert Mulligan',
#  'Harper Lee',
#  'Horton Foote',
#  'Gregory Peck',
#  'John Megna',
#  'Frank Overton',
#  'George Roy Hill',
#  'David S. Ward',
#  'Paul Newman',
#  'Robert Redford',
#  'Robert Shaw',
#  'Asghar Farhadi',
#  'Payman Maadi',
#  'Leila Hatami',
#  'Sareh Bayat',
#  'Thomas Kail',
#  'Lin-Manuel Miranda',
#  'Ron Chernow',
#  'Phillipa Soo',
#  'Leslie Odom Jr.',
#  'Jeffrey Boam',
#  'Menno Meyjes',
#  'Sean Connery',
#  'Alison Doody',
#  'John McTiernan',
#  'Roderick Thorp',
#  'Jeb Stuart',
#  'Steven E. de Souza',
#  'Bruce Willis',
#  'Alan Rickman',
#  'Bonnie Bedelia',
#  'Brigitte Helm',
#  'Alfred Abel',
#  'Gustav Fröhlich',
#  'Amole Gupte',
#  'Darsheel Safary',
#  'Tanay Chheda',
#  'Guy Ritchie',
#  'Jason Statham',
#  'Stephen Graham',
#  'Vittorio De Sica',
#  'Cesare Zavattini',
#  'Luigi Bartolini',
#  'Oreste Biancoli',
#  'Lamberto Maggiorani',
#  'Enzo Staiola',
#  'Lianella Carell',
#  'Curtis Hanson',
#  'James Ellroy',
#  'Brian Helgeland',
#  'Krysty Wilson-Cairns',
#  'Dean-Charles Chapman',
#  'George MacKay',
#  'Daniel Mays',
#  'Paul Schrader',
#  'Cybill Shepherd',
#  'Oliver Hirschbiegel',
#  'Bernd Eichinger',
#  'Joachim Fest',
#  'Traudl Junge',
#  'Bruno Ganz',
#  'Alexandra Maria Lara',
#  'Ulrich Matthes',
#  'Nitesh Tiwari',
#  'Piyush Gupta',
#  'Shreyas Jain',
#  'Nikhil Mehrotra',
#  'Sakshi Tanwar',
#  'Fatima Sana Shaikh',
#  'Fulvio Morsella',
#  'Gian Maria Volontè',
#  'Michael Caine',
#  'Ken Watanabe',
#  'Joseph Kosinski',
#  'Jim Cash',
#  'Jack Epps Jr.',
#  'Peter Craig',
#  'Tom Cruise',
#  'Robert Thoeren',
#  'Marilyn Monroe',
#  'Tony Curtis',
#  'Edna Purviance',
#  'Jackie Coogan',
#  'Terence Winter',
#  'Jordan Belfort',
#  'Jonah Hill',
#  'Margot Robbie',
#  'Florian Zeller',
#  'Christopher Hampton',
#  'Olivia Colman',
#  'Mark Gatiss',
#  'Peter Farrelly',
#  'Nick Vallelonga',
#  'Brian Hayes Currie',
#  'Mahershala Ali',
#  'Linda Cardellini',
#  'Joseph L. Mankiewicz',
#  'Mary Orr',
#  'Bette Davis',
#  'Anne Baxter',
#  'George Sanders',
#  'Stanley Kramer',
#  'Abby Mann',
#  'Montgomery Clift',
#  'Spencer Tracy',
#  'Burt Lancaster',
#  'Richard Widmark',
#  'Peter Weir',
#  'Andrew Niccol',
#  'Ed Harris',
#  'Laura Linney',
#  'Paul Thomas Anderson',
#  'Upton Sinclair',
#  'Daniel Day-Lewis',
#  'Paul Dano',
#  'Ciarán Hinds',
#  'Sharon Stone',
#  'Laeta Kalogridis',
#  'Dennis Lehane',
#  'Emily Mortimer',
#  'Masato Ide',
#  'Akira Terao',
#  'Jinpachi Nezu',
#  'Michael Crichton',
#  'David Koepp',
#  'Sam Neill',
#  'Laura Dern',
#  'Jeff Goldblum',
#  'Guillermo del Toro',
#  'Ivana Baquero',
#  'Ariadna Gil',
#  'Sergi López',
#  'M. Night Shyamalan',
#  'Haley Joel Osment',
#  'Toni Collette',
#  'David Webb Peoples',
#  'Gene Hackman',
#  'Ron Howard',
#  'Akiva Goldsman',
#  'Sylvia Nasar',
#  'Ethan Coen',
#  'Joel Coen',
#  'Cormac McCarthy',
#  'Tommy Lee Jones',
#  'Javier Bardem',
#  'Josh Brolin',
#  'John Huston',
#  'B. Traven',
#  'Walter Huston',
#  'Tim Holt',
#  'Eijirô Tôno',
#  'John Carpenter',
#  'Bill Lancaster',
#  'John W. Campbell Jr.',
#  'Kurt Russell',
#  'Wilford Brimley',
#  'Keith David',
#  'David Carradine',
#  'Daryl Hannah',
#  'Terry Gilliam',
#  'Terry Jones',
#  'Graham Chapman',
#  'John Cleese',
#  'Eric Idle',
#  'John Sturges',
#  'Paul Brickhill',
#  'James Clavell',
#  'W.R. Burnett',
#  'Steve McQueen',
#  'James Garner',
#  'Richard Attenborough',
#  'David Reynolds',
#  'Albert Brooks',
#  'Ellen DeGeneres',
#  'Alexander Gould',
#  'Ryûnosuke Akutagawa',
#  'Machiko Kyô',
#  'Masayuki Mori',
#  'David Lynch',
#  'Christopher De Vore',
#  'Eric Bergren',
#  'Anne Bancroft',
#  'Robert Towne',
#  'Faye Dunaway',
#  'Diana Wynne Jones',
#  'Chieko Baishô',
#  'Takuya Kimura',
#  'Tatsuya Gashûin',
#  'Frederick Knott',
#  'Ray Milland',
#  'Robert Cummings',
#  'Aaron Guzikowski',
#  'Jake Gyllenhaal',
#  'Viola Davis',
#  'Victor Fleming',
#  'George Cukor',
#  'Sam Wood',
#  'Margaret Mitchell',
#  'Sidney Howard',
#  'Oliver H.P. Garrett',
#  'Clark Gable',
#  'Vivien Leigh',
#  'Thomas Mitchell',
#  'James McTeigue',
#  'David Lloyd',
#  'Hugo Weaving',
#  'Rupert Graves',
#  'Jake LaMotta',
#  'Joseph Carter',
#  'Peter Savage',
#  'Cathy Moriarty',
#  'Jason Flemyng',
#  'Dexter Fletcher',
#  'Nick Moran',
#  'Juan José Campanella',
#  'Eduardo Sacheri',
#  'Ricardo Darín',
#  'Soledad Villamil',
#  'Pablo Rago',
#  'Ronnie Del Carmen',
#  'Meg LeFauve',
#  'Amy Poehler',
#  'Bill Hader',
#  'Lewis Black',
#  'Martin McDonagh',
#  'Frances McDormand',
#  'Woody Harrelson',
#  'Sam Rockwell',
#  'Jon Watts',
#  'Chris McKenna',
#  'Erik Sommers',
#  'Tom Holland',
#  'Zendaya',
#  'Benedict Cumberbatch',
#  'Danny Boyle',
#  'Irvine Welsh',
#  'John Hodge',
#  'Ewan McGregor',
#  'Ewen Bremner',
#  'Jonny Lee Miller',
#  'Pierre Boulle',
#  'Carl Foreman',
#  'Jack Hawkins',
#  'William H. Macy',
#  'Steve Buscemi',
#  "Gavin O'Connor",
#  'Anthony Tambakis',
#  'Cliff Dorfman',
#  'Nick Nolte',
#  'Joel Edgerton',
#  'Jeff Nathanson',
#  'Frank Abagnale Jr.',
#  'Stan Redding',
#  'Christopher Walken',
#  'Nick Schenk',
#  'Dave Johannson',
#  'Bee Vang',
#  'Christopher Carley',
#  'Sergio Pablos',
#  'Carlos Martínez López',
#  'Jim Mahoney',
#  'Zach Lewis',
#  'Jason Schwartzman',
#  'Rashida Jones',
#  'Hitoshi Takagi',
#  'Noriko Hidaka',
#  'Chika Sakamoto',
#  'Paul Haggis',
#  'F.X. Toole',
#  'Hilary Swank',
#  'David Yates',
#  'Steve Kloves',
#  'J.K. Rowling',
#  'Daniel Radcliffe',
#  'Emma Watson',
#  'Rupert Grint',
#  'Takashi Yamazaki',
#  'Minami Hamabe',
#  'Sakura Ando',
#  'Majid Majidi',
#  'Mohammad Amir Naji',
#  'Amir Farrokh Hashemian',
#  'Bahare Seddiqi',
#  'Hampton Fancher',
#  'Philip K. Dick',
#  'Rutger Hauer',
#  'Sean Young',
#  'John Ridley',
#  'Solomon Northup',
#  'Chiwetel Ejiofor',
#  'Michael Kenneth Williams',
#  'Michael Fassbender',
#  'Richard Linklater',
#  'Kim Krizan',
#  'Ethan Hawke',
#  'Julie Delpy',
#  'Andrea Eckert',
#  'Wes Anderson',
#  'Stefan Zweig',
#  'Hugo Guinness',
#  'Mathieu Amalric',
#  'William Wyler',
#  'Lew Wallace',
#  'Karl Tunberg',
#  'Gore Vidal',
#  'Charlton Heston',
#  'Stephen Boyd',
#  'William Makepeace Thackeray',
#  "Ryan O'Neal",
#  'Marisa Berenson',
#  'Gillian Flynn',
#  'Rosamund Pike',
#  'Neil Patrick Harris',
#  'Mack Swain',
#  'Tom Murray',
#  'Robert Schenkkan',
#  'Andrew Knight',
#  'Andrew Garfield',
#  'Sam Worthington',
#  'Luke Bracey',
#  'Jim Sheridan',
#  'Gerry Conlon',
#  'Terry George',
#  'Pete Postlethwaite',
#  'Alison Crosbie',
#  'Kwang-rim Kim',
#  'Sung-bo Shim',
#  'Kim Sang-kyung',
#  'Kim Roe-ha',
#  'Elia Kazan',
#  'Budd Schulberg',
#  'Malcolm Johnson',
#  'Robert Siodmak',
#  'Karl Malden',
#  'Clyde Bruckman',
#  'Buster Keaton',
#  'Al Boasberg',
#  'Marion Mack',
#  'Glen Cavender',
#  'Michael Cimino',
#  'Deric Washburn',
#  'Louis Garfinkle',
#  'John Cazale',
#  'Damián Szifron',
#  'Julian Loyola',
#  'Germán Servidio',
#  'Darío Grandinetti',
#  'María Marull',
#  'Mónica Villa',
#  'Tom Schulman',
#  'Robert Sean Leonard',
#  'Ingmar Bergman',
#  'Victor Sjöström',
#  'Bibi Andersson',
#  'Ingrid Thulin',
#  'George Miller',
#  'Brendan McCarthy',
#  'Nick Lathouris',
#  'Charlize Theron',
#  'Nicholas Hoult',
#  'Carol Reed',
#  'Graham Greene',
#  'Alexander Korda',
#  'Alida Valli',
#  'Henri-Georges Clouzot',
#  'Georges Arnaud',
#  'Jérôme Géronimi',
#  'Yves Montand',
#  'Charles Vanel',
#  'Peter van Eyck',
#  'Jean C. Havez',
#  'Joseph A. Mitchell',
#  'Kathryn McGuire',
#  'Joe Keaton',
#  'David Silverman',
#  'Jill Culton',
#  'Jeff Pidgeon',
#  'Billy Crystal',
#  'John Goodman',
#  'Mary Gibbs',
#  'Peter Benchley',
#  'Carl Gottlieb',
#  'Roy Scheider',
#  'Richard Dreyfuss',
#  'Sidney Buchman',
#  'Lewis R. Foster',
#  'Myles Connolly',
#  'Jean Arthur',
#  'Claude Rains',
#  'Dean DeBlois',
#  'Chris Sanders',
#  'William Davies',
#  'Jay Baruchel',
#  'Gerard Butler',
#  'Christopher Mintz-Plasse',
#  'Adam Elliot',
#  'Philip Seymour Hoffman',
#  'Eric Bana',
#  'James Mangold',
#  'Jez Butterworth',
#  'John-Henry Butterworth',
#  'Jason Keller',
#  'Jon Bernthal',
#  'Max von Sydow',
#  'Gunnar Björnstrand',
#  'Bengt Ekerot',
#  'Lenny Abrahamson',
#  'Emma Donoghue',
#  'Brie Larson',
#  'Jacob Tremblay',
#  'Sean Bridgers',
#  'Brad Bird',
#  'Jan Pinkava',
#  'Jim Capobianco',
#  'Brad Garrett',
#  'Lou Romano',
#  'Patton Oswalt',
#  'Jeff Bridges',
#  'Julianne Moore',
#  'Yasujirô Ozu',
#  'Kôgo Noda',
#  'Chishû Ryû',
#  'Chieko Higashiyama',
#  'Sô Yamamura',
#  'John G. Avildsen',
#  'Sylvester Stallone',
#  'Talia Shire',
#  'Burt Young',
#  'Keir Pearson',
#  'Don Cheadle',
#  'Sophie Okonedo',
#  'Scott Frank',
#  'Michael Green',
#  'Patrick Stewart',
#  'Dafne Keen',
#  'Josh Singer',
#  'Michael Keaton',
#  'Rachel McAdams',
#  'Charlie Sheen',
#  'Tom Berenger',
#  'Willem Dafoe',
#  'Carl Theodor Dreyer',
#  'Joseph Delteil',
#  'Maria Falconetti',
#  'Eugene Silvain',
#  'André Berley',
#  'Gale Anne Hurd',
#  'Vernon Dobtcheff',
#  'T.J. Gnanavel',
#  'Rajendra Sapre',
#  'Suriya',
#  'Lijo Mol Jose',
#  'Manikandan K.',
#  'Peter Morgan',
#  'Daniel Brühl',
#  'Olivia Wilde',
#  'Paddy Chayefsky',
#  'Peter Finch',
#  'William Friedkin',
#  'William Peter Blatty',
#  'Linda Blair',
#  'Robert E. Sherwood',
#  'MacKinlay Kantor',
#  'Myrna Loy',
#  'Dana Andrews',
#  'Fredric March',
#  'Rob Reiner',
#  'Raynold Gideon',
#  'Bruce A. Evans',
#  'Wil Wheaton',
#  'River Phoenix',
#  'Corey Feldman',
#  'Vincent Cassel',
#  'Hubert Koundé',
#  'Saïd Taghmaoui',
#  'Gore Verbinski',
#  'Ted Elliott',
#  'Terry Rossio',
#  'Stuart Beattie',
#  'Johnny Depp',
#  'Geoffrey Rush',
#  'King Vidor',
#  'Noel Langley',
#  'Florence Ryerson',
#  'Edgar Allan Woolf',
#  'Judy Garland',
#  'Frank Morgan',
#  'Ray Bolger',
#  'Craig T. Nelson',
#  'Holly Hunter',
#  'Sean Penn',
#  'Jon Krakauer',
#  'Emile Hirsch',
#  'Vince Vaughn',
#  'Catherine Keener',
#  'Lasse Hallström',
#  'Stephen P. Lindsey',
#  'Kaneto Shindô',
#  'Richard Gere',
#  'Joan Allen',
#  'Cary-Hiroyuki Tagawa',
#  'Sarah Waters',
#  'Chung Seo-kyung',
#  'Kim Min-hee',
#  'Ha Jung-woo',
#  'Cho Jin-woong',
#  'Ernst Lubitsch',
#  'Melchior Lengyel',
#  ...]

# %% [markdown]
# ##### Заполнение таблицы Person

# %%
for person in person_list:
    cursor.execute("INSERT INTO Person(name) VALUES (?);", (person,))

# %%
cursor.execute("SELECT * FROM Person;")
person_rows = cursor.fetchall()

# %%
print(person_rows[:20])
# Out:
# [(1, 'Frank Darabont'), (2, 'Stephen King'), (3, 'Tim Robbins'), (4, 'Morgan Freeman'), (5, 'Bob Gunton'), (6, 'Francis Ford Coppola'), (7, 'Mario Puzo'), (8, 'Marlon Brando'), (9, 'Al Pacino'), (10, 'James Caan'), (11, 'Christopher Nolan'), (12, 'Jonathan Nolan'), (13, 'David S. Goyer'), (14, 'Christian Bale'), (15, 'Heath Ledger'), (16, 'Aaron Eckhart'), (17, 'Robert De Niro'), (18, 'Robert Duvall'), (19, 'Sidney Lumet'), (20, 'Reginald Rose')]

# %%
person_to_id = dict()
for person in person_rows:
    person_to_id[person[1]] = person[0]

# %% [markdown]
# ##### Заполнение таблицы Genre

# %%
for genre in genre_list:
    cursor.execute("INSERT INTO Genre(name) VALUES (?);", (genre,))

# %%
cursor.execute("SELECT * FROM Genre;")
genre_rows = cursor.fetchall()

# %%
print(genre_rows)
# Out:
# [(1, 'Drama'), (2, 'Crime'), (3, 'Action'), (4, 'Biography'), (5, 'History'), (6, 'Adventure'), (7, 'Western'), (8, 'Romance'), (9, 'Sci-Fi'), (10, 'Fantasy'), (11, 'Mystery'), (12, 'Family'), (13, 'Thriller'), (14, 'War'), (15, 'Comedy'), (16, 'Animation'), (17, 'Music'), (18, 'Horror'), (19, 'Film-Noir'), (20, 'Musical'), (21, 'Sport')]

# %%
genre_to_id = dict()
for genre in genre_rows:
    genre_to_id[genre[1]] = genre[0]

# %% [markdown]
# ##### Заполнение таблицы Movie

# %%
for movie in movies_res:
    cursor.execute('''
                   INSERT INTO Movie(rank, rating, vote_count,
                                     year, title, description, duration)
                   VALUES (?, ?, ?, ?, ?, ?, ?);''',
                   (movie.rank, movie.rating_str, movie.vote_count,
                   movie.year, movie.title, movie.description, movie.duration)
                  )

# %% [markdown]
# ##### Заполнение связующих таблиц

# %%
for movie in movies_res:
    for d in movie.directors:        
        cursor.execute('''INSERT INTO MovieDirector(movie_id, director_id) VALUES (?, ?);''',
                (movie.rank, person_to_id[d]))
    for w in movie.writers:        
        cursor.execute('''INSERT INTO MovieWriter(movie_id, writer_id) VALUES (?, ?);''',
                (movie.rank, person_to_id[w]))
    for s in movie.stars:        
        cursor.execute('''INSERT INTO MovieStar(movie_id, star_id) VALUES (?, ?);''',
                (movie.rank, person_to_id[s]))
    for g in movie.genres:        
        cursor.execute('''INSERT INTO MovieGenre(movie_id, genre_id) VALUES (?, ?);''',
                (movie.rank, genre_to_id[g]))
    for vote, vote_count in movie.rating_dist.items():
        cursor.execute('''INSERT INTO MovieRatingDist VALUES (?, ?, ?);''',
                (movie.rank, vote, vote_count))

# %%
conn.commit()
